# %% [markdown]
# # <center>Residential Solar Panel Size Prediction </center>

# %% [markdown]
# Author: Sayantan Mitra<br>
# Chief Data Scientist, Crompton & Wendler<br>
# Ph.D. candidate, Baylor College of Medicine

# %% [markdown]
# <div style="text-align: right">
# *The Nation that leads in renewable energy will be the nation that leads the world* —James Cameron </div>

# %% [markdown]
# The 21st Century has borne witness to severe global environmental problems including polar ice-cap melting, frequent earthquakes in southeast Asia, and consequent tsunamis. Scientists have connected these problems to climate change. Across the globe, people have become more aware of the need for clean energy. The sun has been and will always remain the largest source of energy for the planet. Solar power has been harnessed in the last few decades but people have hesitated to adopt this capacity on a mass scale. Concerns range from solar energy's applicability and safety for residential homes to the amount of solar panels required to replace conventional energy sources.
#
# In this project, I take a step toward demystifying the size of solar panels needed to completely eliminate reliance on traditional electricity. There are a lot of factors involved in efficient solar energy production and we will comprehensively address them throughout the project. Data for this project has been collected from [National Renewable Energy Laboratory](https://openpv.nrel.gov/search).
#
# ## ► <span  style="color:blue; font-size:15px"> Objective: Predict size of solar panels for residential setting</span>
#
# Here is a video to learn how home solar panels work!
#
# [![How Home Solar Panel Works](http://img.youtube.com/vi/m6UgO6-HELc/0.jpg)](http://www.youtube.com/watch?v=m6UgO6-HELc)

# %% [markdown]
# # Contents of the Notebook:

# %% [markdown]
# # 1. Exploratory Data Analysis (EDA)

# %% [markdown]
# # 1.A. Import libraries

# %%
import numpy as np
import pandas as pd
import pandas_profiling as pf
from collections import Counter

# VisualiZation
from termcolor import colored
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# Configure visualisations
# %matplotlib inline
plt.style.use('ggplot')

# ignore warnings
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 1.B. Load data
# We can have basic information of the columns and about data overall, stored in the form of a dictionary.

# %%
pd.options.display.max_colwidth = 100
solar_dictionary = pd.read_excel('solar_sizepred_datadict.xlsx', index_col='Column Names')
solar_dictionary
# Out:
#                                                                                                      Description
# Column Names
# state                                                                          Which state the customer belongs
# date_installed                                                                How long ago it has been installed
# incentive_prog_names                                                   Incentive programs specific to the states
# size_kw                                                             Size of the solar panels installed (TARGET)
# zipcode                                                                                        customers zipcode
# install_type                                                                    customers pupose of installation
# installer                                                                    Installing company for solar panels
# city                                                                              Which city customer belongs to
# tech_1                                        Different types of solar panels that determins solar panel quality
# county                                                                                          Customers county
# annual_PV_prod                                                   Annual predicted photovoltaic energy production
# annual_insolation                                                                               solar insolation
# tracking_type         Different tracking type solar panels (they have different efficiency of energy production)

# %% [markdown]
# Raw data from National Renewable Energy Laboratory was cleaned and features that consumers can not relate to are removed.

# %%
solar = pd.read_csv('solar_sizepred.csv', parse_dates=['date_installed']) 
solar.head()
# Out:
#   state date_installed incentive_prog_names  size_kw  zipcode install_type  \
# 0    TX     2013-12-12        Austin Energy    10.56    78702  residential
# 1    TX     2014-07-11        Austin Energy    12.72    78702  residential
# 2    TX     2014-01-17        Austin Energy     5.40    78702  residential
# 3    TX     2012-09-27        Austin Energy     7.50    78702  residential
# 4    TX     2012-09-26        Austin Energy     5.00    78702  residential
#
#   installer    city tech_1  county  annual_PV_prod  annual_insolation  \
# 0       NaN  AUSTIN   Poly  Travis    14999.831600           5.157692
# 1       NaN  AUSTIN   Mono  Travis    17811.574390           5.085633
# 2       NaN  AUSTIN   Mono  Travis     7833.742822           5.262714
# 3       NaN  AUSTIN   Poly  Travis    10151.709590           4.920972
# 4       NaN  AUSTIN   Poly  Travis     7307.133789           5.304778
#
#   tracking_type
# 0         Fixed
# 1         Fixed
# 2         Fixed
# 3         Fixed
# 4         Fixed

# %%
# Overall statistics of the numerical columns
solar.describe(percentiles=[.25,.5,.75,.9,.975])
# Out:
#              size_kw        zipcode  annual_PV_prod  annual_insolation
# count  542618.000000  542618.000000    5.426180e+05      542618.000000
# mean       11.612236   68646.935190    1.674957e+04           5.264753
# std        80.877078   37362.444983    1.094119e+05           0.765272
# min         0.050000    1001.000000    8.765472e+01           1.177450
# 25%         3.900000   19426.500000    5.640710e+03           4.544056
# 50%         5.640000   91342.000000    8.251434e+03           5.374999
# 75%         8.041338   93274.000000    1.173740e+04           5.685442
# 90%        11.000000   95066.000000    1.636997e+04           6.497946
# 97.5%      27.540000   95765.000000    3.966079e+04           6.510539
# max      5999.930000   97914.000000    9.300156e+06           6.761269

# %% [markdown]
# We will only select residential data and upto 40 Kw. For residential setting people will install as big as 40kw. Any bigger installation are generally anomaly based on record-research.

# %%
# Range of residential is upto 40kWh generally
filt1 = solar['install_type'] == 'residential'
filt2 = (solar['size_kw'] > 0) & (solar['size_kw'] < 40)
solar = solar[filt1 & filt2]

# All residential so drop column 'install_type'
solar = solar.drop(columns=['install_type'])
solar.shape
# Out:
# (487253, 12)

# %%
solar.isna().mean().round(3)
f,ax=plt.subplots(figsize=(12,6))
missing = solar.isna().mean()
missing[missing>0].plot.bar(ax=ax)
ax.set_xticklabels(ax.get_xticklabels(),rotation=0, fontsize=15)
f.suptitle('Count of missing values', fontsize=20, y=.95);

# %% [markdown]
# ♦ **Initial observation:**
# `installer`, `tech_1`, and `tracking_type` columns contain missing values. Here we will replace them with `Unknown`

# %%
# Check whether the missing value might have any predictive power
# Using median as 'size_kw' is not gaussian distribution
a = solar.dropna()['size_kw'].median()
b = solar.loc[solar['installer'].isna(),['size_kw']].median()[0].round(2)
c = solar.loc[solar['tech_1'].isna(),['size_kw']].median()[0].round(2)
d = solar.loc[solar['tracking_type'].isna(),['size_kw']].median()[0].round(2)

print(f'Overall solar panel size in residential housing without missing values: {a}\n')
print(f'Overall solar panel size in when installer data is missing: {b}\n')
print(f'Overall solar panel size in when tech_1 data is missing: {c}\n')
print(f'Overall solar panel size in when tracking_type data is missing: {d}\n')
# Out:
# Overall solar panel size in residential housing without missing values: 5.39
#
# Overall solar panel size in when installer data is missing: 6.27
#
# Overall solar panel size in when tech_1 data is missing: 6.21
#
# Overall solar panel size in when tracking_type data is missing: 5.94

# %% [markdown]
# Missing values could be predictive, so we can create a separate missingness capture column. This is specially useful when monotonic relatiosnhip is generated between categorial column and target during categorical encoding. However missingness capture column doesnt improve the prediction performance, so I took it out.

# %%
# capture missingness of data
def impute_na(df, col):
    #df[col + '_NA'] = np.where(df[col].isna(), 1, 0) 
    df[col].fillna("Unknown", inplace=True)
    
cols = ['installer', 'tech_1', 'tracking_type']
for col in cols:
    impute_na(solar, col)
    
print(f'Missing values after imputation: {solar.isna().sum().sum()}')
# Out:
# Missing values after imputation: 0

# %% [markdown]
# # 1.C. Feature Engineering

# %%
# Zipcode: extract initial numbers of zipcode to see impact on energy production if area is classified largely
solar['zipcode_1'] = solar['zipcode'].astype('str').str[:1].astype(int)
solar['zipcode_2'] = solar['zipcode'].astype('str').str[:2].astype(int)
solar['zipcode_3'] = solar['zipcode'].astype('str').str[:3].astype(int)

# DateTime column: extract year and month of installation
date = solar['date_installed']
solar['year'] =  date.dt.year
solar['month'] = date.dt.month

# solar_x will be a copy of the data at this stage (before taking care of cardinality)
solar_x = solar.copy()

# %%
solar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 487253 entries, 0 to 542617
# Data columns (total 17 columns):
# state                   487253 non-null object
# date_installed          487253 non-null datetime64[ns]
# incentive_prog_names    487253 non-null object
# size_kw                 487253 non-null float64
# zipcode                 487253 non-null int64
# installer               487253 non-null object
# city                    487253 non-null object
# tech_1                  487253 non-null object
# county                  487253 non-null object
# annual_PV_prod          487253 non-null float64
# annual_insolation       487253 non-null float64
# tracking_type           487253 non-null object
# zipcode_1               487253 non-null int32
# zipcode_2               487253 non-null int32
# zipcode_3               487253 non-null int32
# year                    487253 non-null int64
# month                   487253 non-null int64
# dtypes: datetime64[ns](1), float64(3), int32(3), int64(3), object(7)
# memory usage: 61.3+ MB

# %%
# Divide data into train and test # Use this test as a validation set later on
solar_train, solar_val = train_test_split(solar, test_size=0.2, random_state= 0)
solar = solar_train

# %% [markdown]
# ► Unique values in some categorical columns such as `installer`, `city`, `county`, etc. are large. Generally cardinality leads to more problems in tree based models. We will only retain the categories in a categorical column that has 1% or more appearances. The remaining categories in that column will be aggregated as `Others`. This process will be done for both the train and test set.

# %% [markdown]
# ### Cardinality reduction

# %%
solar.describe(include=['O']).T
# Out:
#                        count unique  \
# state                 389802     19
# incentive_prog_names  389802     47
# installer             389802   5960
# city                  389802   7568
# tech_1                389802     12
# county                389802    479
# tracking_type         389802      5
#
#                                                                                        top  \
# state                                                                                   CA
# incentive_prog_names  California Public Utilities Commission (California Solar Initiative)
# installer                                                                        SolarCity
# city                                                                                TUCSON
# tech_1                                                                                Poly
# county                                                                         Los Angeles
# tracking_type                                                                        Fixed
#
#                         freq
# state                 209433
# incentive_prog_names  112684
# installer              90439
# city                    7736
# tech_1                175819
# county                 37370
# tracking_type         273985

# %%
solar_val.describe(include=['O']).T
# Out:
#                       count unique  \
# state                 97451     19
# incentive_prog_names  97451     45
# installer             97451   3522
# city                  97451   4982
# tech_1                97451     12
# county                97451    397
# tracking_type         97451      5
#
#                                                                                        top  \
# state                                                                                   CA
# incentive_prog_names  California Public Utilities Commission (California Solar Initiative)
# installer                                                                        SolarCity
# city                                                                                TUCSON
# tech_1                                                                                Poly
# county                                                                         Los Angeles
# tracking_type                                                                        Fixed
#
#                        freq
# state                 52440
# incentive_prog_names  28136
# installer             22558
# city                   1850
# tech_1                44016
# county                 9424
# tracking_type         68409

# %%
def group_levels_in_categoricals(df, threshold=0.01, min_freq=0, max_freq=np.Inf):
    df0 = df.describe(include=['O']).T
    reduced_list = df0[(df0.unique < max_freq) & (df0.unique > min_freq)].reset_index()['index'].tolist()
    # reduced list is name of categorical columns
    
    patterns = []
    #patterns will contain list of all categories of all categorical column whose occurance is more than threshold
    other = []
    
    for col in reduced_list:
        df_normalized = df[col].value_counts(normalize=True).reset_index()
        df_normalized.columns = ['col_name', 'normalized_value']
        filt = df_normalized['normalized_value'] > threshold
        norm_list = df_normalized[filt]['col_name'].tolist()
        # norm_list contains all the categories in a categorical column whose occurance is more than threshold
        
        pattern = norm_list
        patterns.append(norm_list)
        
        # selecting categories that are present less than threshold
        others_list = df_normalized[~filt]['col_name'].tolist()
        other.append(others_list)
        
        if pattern != []: 
            df[col] = df[col].replace({x:'Other' for x in others_list})
        
        else:
            df.drop(col, inplace=True, axis=1)
    
    return (df, patterns, reduced_list, other)

df, patterns, reduced_list, other = group_levels_in_categoricals(solar)

# solar training set after transformation
solar.describe(include=['O']).T
# Out:
#                        count unique  \
# state                 389802     12
# incentive_prog_names  389802     18
# installer             389802     12
# city                  389802      7
# tech_1                389802      5
# county                389802     23
# tracking_type         389802      3
#
#                                                                                        top  \
# state                                                                                   CA
# incentive_prog_names  California Public Utilities Commission (California Solar Initiative)
# installer                                                                            Other
# city                                                                                 Other
# tech_1                                                                                Poly
# county                                                                               Other
# tracking_type                                                                        Fixed
#
#                         freq
# state                 209433
# incentive_prog_names  112684
# installer             179191
# city                  354837
# tech_1                175819
# county                125813
# tracking_type         273985

# %%
# We have to keep this consistent with test data as well
def group_levels_in_categoricals_test(reduced_list, other, patterns, df_test):
    
    for idx, col in enumerate(reduced_list):       
        if other[idx] != []:
            filt = df_test[col].isin(patterns[idx])
            df_test[col][~filt]='Others'
        else:
            df_test.drop(col, inplace=True, axis=1)
            
    return df_test

solar_val = group_levels_in_categoricals_test(reduced_list, other, patterns, solar_val)

# solar validation set after transformation
solar_val.describe(include=['O']).T
# Out:
#                       count unique  \
# state                 97451     12
# incentive_prog_names  97451     18
# installer             97451     12
# city                  97451      7
# tech_1                97451      5
# county                97451     23
# tracking_type         97451      3
#
#                                                                                        top  \
# state                                                                                   CA
# incentive_prog_names  California Public Utilities Commission (California Solar Initiative)
# installer                                                                           Others
# city                                                                                Others
# tech_1                                                                                Poly
# county                                                                              Others
# tracking_type                                                                        Fixed
#
#                        freq
# state                 52440
# incentive_prog_names  28136
# installer             44943
# city                  88833
# tech_1                44016
# county                31327
# tracking_type         68409

# %% [markdown]
# ♦ Solar train and test set categorical columns have the same number of unique values.

# %%
# Overall summary of the dataset
pf.ProfileReport(solar)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>18 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>389802 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>49.1 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>132.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>7 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_annual_PV_prod"><code>annual_PV_prod</code></a> is highly correlated with <a href="#pp_var_size_kw"><code>size_kw</code></a> (ρ = 0.96247) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_zipcode_1"><code>zipcode_1</code></a> is highly correlated with <a href="#pp_var_zipcode"><code>zipcode</code></a> (ρ = 0.93649) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_zipcode_2"><code>zipcode_2</code></a> is highly correlated with <a href="#pp_var_zipcode_1"><code>zipcode_1</code></a> (ρ = 0.99714) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_zipcode_3"><code>zipcode_3</code></a> is highly correlated with <a href="#pp_var_zipcode_2"><code>zipcode_2</code></a> (ρ = 0.99996) <span class="label label-primary">Rejected</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow ignore">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_annual_PV_prod"><s>annual_PV_prod</s><br/>
#             <small>Highly correlated</small>
#         </p>
#     </div><div class="col-md-3">
#     <p><em>This variable is highly cor

# %% [markdown]
# # 2.A. Explore target variable: `size_kw`

# %%
import scipy.stats as st
from scipy.stats import norm, skew # for some statistics
fig, axes = plt.subplots(1,2, figsize = (12,5))

sns.distplot(solar['size_kw'], fit=norm, ax=axes[0])
# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(solar['size_kw'])
print( 'mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

# plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
plt.ylabel('Frequency')
plt.title('Size_kw distribution')

# Get also the QQ-plot
res = st.probplot(solar['size_kw'], plot=plt)
plt.show()

print("Skewness: %f" % solar['size_kw'].skew())
print("Kurtosis: %f" % solar['size_kw'].kurt())
# Out:
# mu = 6.18 and sigma = 3.26
# Skewness: 1.738892
# Kurtosis: 7.025893

# %% [markdown]
# → The target variable is clearly right skewed. So we have to transform the target variable before running regression.

# %%
# We use the numpy fuction log1p which  applies log(1+x) to all elements of the column
solar['size_kw_L'] = np.log1p(solar['size_kw'])
solar_val['size_kw_L'] = np.log1p(solar_val['size_kw'])
fig, axes = plt.subplots(1,2, figsize = (12,5))
#Check the new distribution 
sns.distplot(solar['size_kw_L'], fit=norm, ax=axes[0]);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(solar['size_kw_L'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
plt.ylabel('Frequency')
plt.title('Size_kw distribution')

#Get also the QQ-plot
res = st.probplot(solar['size_kw_L'], plot=plt)
plt.show()

print("Skewness: %f" % solar['size_kw_L'].skew())
print("Kurtosis: %f" % solar['size_kw_L'].kurt())
# Out:
#  mu = 1.88 and sigma = 0.43
# Skewness: -0.040941
# Kurtosis: 0.122032

# %% [markdown]
# → After log transformation, target variable follows normal distribution.

# %% [markdown]
# # 2.B. Column-wise relationship

# %%
# EDA: Correlation matrix among all features will inform us relationship between features
sns.set(style='white', font_scale = 1)

# Correlation matrix
corr = solar.corr().round(3)
# Generate mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up matplotlib figure
f,ax = plt.subplots(figsize= (10,6))
f.suptitle('Correlation among features', x=0.5, y=.9, fontsize = 15)

# Generate custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw heatmap with the mask and correct aspect ratio
sns.heatmap(corr, annot=True, annot_kws={'size': 8}, mask=mask, cmap=cmap, vmax=.3, 
                                    center=0, square=True, linewidths=.5, cbar_kws={'shrink':.5})

# %% [markdown]
# ♦ **Initial observation:** <br>
# → As expected `size_kw` and `annual_PV_prod` are highly correlated. <br>

# %% [markdown]
# Except some obvious high correlations (eg-between zipcodes and between size_kw-size_kw_L), there are not any high correlations between features that I will use in ML, thus we don't have to worry about multi-collinearity.

# %%
# EDA: Correlation with target
plt.style.use('ggplot')
solar2 = solar.drop(columns=['size_kw', 'size_kw_L']) #, 'annual_PV_prod_L'
solar2.corrwith(solar['size_kw_L']).plot.bar(figsize=(10,5),
                                               title = 'Feature corrlation with size_kw (Target)',
                                               fontsize = 12, rot = 45)

# %% [markdown]
# ♦ **Initial observation:** <br>
# → As expected, the size of solar panels are strongly correlated with annual energy production.  <br>

# %% [markdown]
# # 2.C. Analysis of individual features
#
# ## Types of Features
# The 2 broad classes of variables in the dataset are categorical and continuous.
#
# ### Categorical Features:
# A categorical variable is one that is limited to a finite number of categories. Categories can be labels or discrete numerical values. For example, gender is a categorical variable having two categories (male and female). Categorical features can be further divided into ordinal and nominal data.
#
# • **Ordinal data** has a natural ordering but the difference between the orders is not measurable. For example, stage 4 cancer is worse than stage 3 (an order), but we cannot quantify how much worse. <br>
# • **Nominal data** are categorical data without any natural ordering. For example, all available hair color dyes.<br>
# ► Categorical features in the dataset are updated in the data dictionary below.
# ### Continuous Features:
# A continuous variable can take an infinite set of numerical values. <br>
# ► Continuous features in the dataset are updated in the data dictionary below.

# %%
# select features with <20 unique elements as categories 
solar.nunique()
# Out:
# state                       12
# date_installed            4426
# incentive_prog_names        18
# size_kw                  16837
# zipcode                   7535
# installer                   12
# city                         7
# tech_1                       5
# county                      23
# annual_PV_prod          244308
# annual_insolation        61450
# tracking_type                3
# zipcode_1                    8
# zipcode_2                   71
# zipcode_3                  524
# year                        17
# month                       12
# size_kw_L                16837
# dtype: int64

# %%
# update data dictionary about feature type
solar_dictionary.drop(solar_dictionary.index[5:6], inplace=True)
solar_dictionary.loc['month']= 'month of installation'
solar_dictionary.loc['year']= 'year of installation'
solar_dictionary.loc['zipcode_1']= '1st number of zipcode'
solar_dictionary.loc['zipcode_2']= 'First 2 number of zipcode'
solar_dictionary.loc['zipcode_3']= 'First 3 number of zipcode'

c, o, n, d = 'continuous', 'ordinal', 'nominal', 'datetime'
d = {'size_kw':c, 'annual_PV_prod':c, 'annual_insolation':c, 'zipcode':o, 'zipcode_1':o, 'zipcode_2':o,
     'zipcode_3':o, 'year':o, 'month':o, 'tech_1':o, 'date_installed': d, 'state': n, 'city': n, 'county': n,
    'incentive_prog_names': n, 'installer': n, 'tracking_type':n}
solar_dictionary['Feature Info'] = pd.Series(d)
solar_dictionary
# Out:
#                                                                                                      Description  \
# Column Names
# state                                                                          Which state the customer belongs
# date_installed                                                                How long ago it has been installed
# incentive_prog_names                                                   Incentive programs specific to the states
# size_kw                                                             Size of the solar panels installed (TARGET)
# zipcode                                                                                        customers zipcode
# installer                                                                    Installing company for solar panels
# city                                                                              Which city customer belongs to
# tech_1                                        Different types of solar panels that determins solar panel quality
# county                                                                                          Customers county
# annual_PV_prod                                                   Annual predicted photovoltaic energy production
# annual_insolation                                                                               solar insolation
# tracking_type         Different tracking type solar panels (they have different efficiency of energy production)
# month                                                                                      month of installation
# year                                                                                        year of installation
# zipcode_1                                                                                  1st number of zipcode
# zipcode_2                                                                              First 2 number of zipcode
# zipcode_3                                                                              First 3 number of zipcode
#
#                      Feature Info
# Column Names
# state                     nominal
# date_installed           datetime
# incentive_prog_names      nominal
# size_kw                continuous
# zipcode                   ordinal
# installer                 nominal
# city                      nominal
# tech_1                    ordinal
# county                    nominal
# annual_PV_prod         continuous
# annual_insolation      continuous
# tracking_type             nominal
# month                     ordinal
# year                      ordinal
# zipcode_1                 ordinal
# zipcode_2                 ordinal
# zipcode_3                 ordinal

# %% [markdown]
# # 2.D. Analyzing numerical features

# %%
# Select numerical columns
solar_num = solar.select_dtypes(include=['number'])
solar_num = solar_num[['annual_PV_prod', 'annual_insolation', 'size_kw', 'size_kw_L']]

# EDA: Distribution of individual numerical features
fig, axes = plt.subplots(1,4, figsize=(18,4), gridspec_kw = {'wspace':0.25, 'hspace':0.30})
axes = axes.ravel()
st = fig.suptitle('Histogram of Numerical Columns', fontsize = 20)
st.set_y(1.05)

for i in range(solar_num.shape[1]):
    axes[i].hist(solar_num.iloc[:, i],color = '#3F5D7D')
    axes[i].set_title(solar_num.columns[i].capitalize())

fig.tight_layout()

# %% [markdown]
# ♦ **Initial observation:** <br>
# → `size_kw` follows normal distribution once it has been log transformed (`size_kw_L`). <br>
# → `Annual_insolation` and `annual_PV_prod` are not normally distributed. **For linear model, one of the assumption is to have predictors in the gaussian distribution. Thus, we need to transform atleast `annual_PV_prod` (as it is a good predictor) feature into a gaussian distribution.**<br>

# %% [markdown]
# ## `annual_PV_prod`: Annual photovoltaic energy production

# %%
solar.plot.scatter(x='annual_PV_prod', y='size_kw_L', ylim=(0,4), color = '#3F5D7D')

import scipy.stats as st
from scipy.stats import norm, skew # for some statistics
fig, axes = plt.subplots(1,2, figsize=(12, 4), gridspec_kw = {'wspace':0.25, 'hspace':0.30})

sns.distplot(solar['annual_PV_prod'], kde=False, fit=norm, ax=axes[0], color = '#3F5D7D')

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(solar['annual_PV_prod'])
#print( 'mu = {:.2f} and sigma = {:.2f}'.format(mu, sigma))

#Now plot the distribution
axes[0].legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Annual_PV_prod distribution')

#Get also the QQ-plot
res = st.probplot(solar['annual_PV_prod'], plot=plt)
plt.show()

print("Skewness: %f" % solar['annual_PV_prod'].skew())
print("Kurtosis: %f" % solar['annual_PV_prod'].kurt())
# Out:
# Skewness: 1.916084
# Kurtosis: 8.070087

# %% [markdown]
# ♦ **Initial observation:** <br>
# → The `annual_PV_prod` variable is clearly right skewed. So we have to transform it like the target variable before running regression.
#
# → Below we observe that log transformation of `annual_PV_prod` allowed it to follow normal distribution.

# %%
import scipy.stats as st
from scipy.stats import norm, skew # for some statistics
fig, axes = plt.subplots(1,2, figsize=(12,4), gridspec_kw = {'wspace':0.25, 'hspace':0.30})

#We use the numpy fuction log1p which  applies log(1+x) to all elements of the column
solar['annual_PV_prod_L'] = np.log1p(solar['annual_PV_prod'])
solar_val['annual_PV_prod_L'] = np.log1p(solar_val['annual_PV_prod'])

#Check the new distribution 
sns.distplot(solar['annual_PV_prod_L'], fit=norm, ax=axes[0], color = '#3F5D7D')

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(solar['annual_PV_prod_L'])
print( 'mu = {:.2f} and sigma = {:.2f}'.format(mu, sigma))

#Now plot the distribution
axes[0].legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Annual_PV_prod distribution')

#Get also the QQ-plot
res = st.probplot(solar['annual_PV_prod_L'], plot=plt)
plt.show()

print("Skewness: %f" % solar['annual_PV_prod_L'].skew())
print("Kurtosis: %f" % solar['annual_PV_prod_L'].kurt())
# Out:
# mu = 8.98 and sigma = 0.53
# Skewness: -0.285053
# Kurtosis: 0.587433

# %% [markdown]
# ## `annual_insolation`: Amount of solar radiation falling on a particular area

# %%
f, ax = plt.subplots(1,2, figsize=(12,4), gridspec_kw = {'wspace':0.25, 'hspace':0.30})
solar.plot.scatter(x='annual_insolation', y='size_kw', ax=ax[0], color = '#3F5D7D')
solar.plot.scatter(x='annual_insolation', y='annual_PV_prod', ax=ax[1], color = '#3F5D7D')

# %% [markdown]
# ♦ **Initial observation:** <br>
#
# → Insolation's relation with `size_kw` is not clear from the data (because although the size of solar panel installed can be dependent on solar radiation in a particular area, it is more likely to be based on the energy consumption in that particular household). <br>
#
# → As expected with an increase in `annual_insolation`, `annual_PV_prod` increases. So to produce the same amount of energy, an area with higher insolation will need to install less `size_kw` and vice versa. However, we see a large range of the amount of energy production at higher insolation. This disparity might be due to how many solar panels are installed, the quality of solar panel efficiency in producing energy, etc.

# %% [markdown]
# # 2.E. Analyzing categorical features

# %% [markdown]
# ## `year`: year of installation of solar panels

# %%
solar.pivot_table(index='year', columns='month', values='size_kw', 
                               fill_value=0, aggfunc='size').style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row0_col0 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row0_col1 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row0_col2 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row0_col3 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row0_col4 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row0_col5 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row0_col6 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row0_col7 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row0_col8 {
#             background-color:  #f3f966;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row0_col9 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row0_col10 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row0_col11 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row1_col0 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row1_col1 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row1_col2 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row1_col3 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row1_col4 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row1_col5 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row1_col6 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row1_col7 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row1_col8 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row1_col9 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row1_col10 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row1_col11 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row2_col0 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row2_col1 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row2_col2 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row2_col3 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row2_col4 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row2_col5 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row2_col6 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row2_col7 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row2_col8 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row2_col9 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row2_col10 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row2_col11 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row3_col0 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row3_col1 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row3_col2 {
#             background-color:  #fefe66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row3_col3 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row3_col4 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row3_col5 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row3_col6 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row3_col7 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row3_col8 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row3_col9 {
#             background-color:  #fefe66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row3_col10 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row3_col11 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row4_col0 {
#             background-color:  #fefe66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row4_col1 {
#             background-color:  #fefe66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row4_col2 {
#             background-color:  #fefe66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row4_col3 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row4_col4 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row4_col5 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row4_col6 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row4_col7 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row4_col8 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row4_col9 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row4_col10 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row4_col11 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row5_col0 {
#             background-color:  #fefe66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row5_col1 {
#             background-color:  #fefe66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row5_col2 {
#             background-color:  #fefe66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row5_col3 {
#             background-color:  #fefe66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row5_col4 {
#             background-color:  #fefe66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row5_col5 {
#             background-color:  #fefe66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row5_col6 {
#             background-color:  #fefe66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row5_col7 {
#             background-color:  #fefe66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row5_col8 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row5_col9 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row5_col10 {
#             background-color:  #fefe66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row5_col11 {
#             background-color:  #ffff66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row6_col0 {
#             background-color:  #fcfe66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row6_col1 {
#             background-color:  #fdfe66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row6_col2 {
#             background-color:  #fcfe66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row6_col3 {
#             background-color:  #fdfe66;
#         }    #T_8cb278b6_8cab_11e9_ab20_a86bad717d32row6_col4 {

# %%
f,ax = plt.subplots(figsize=(12,4))
solar_year = solar.groupby('year').agg({'size_kw':'mean'})
solar_year.plot(ax=ax)


def value_count_plot(data, col, sort, ascending, ax, xlabel, title, size, fontsize, font, rotation=0):
    data[col].value_counts(sort=sort).plot.bar(ax=ax)
    ax.set_xlabel(xlabel, fontsize = font, labelpad = 10)
    ax.set_xticklabels(ax.get_xticklabels(), fontsize = fontsize, rotation = rotation)
    ax.set_title(title, size=size)
    
def cat_box_plot(x, y, data, ax, xlabel, title, size, fontsize, font, rotation=0):
    sns.boxplot(x, y, data=data, ax=ax)
    ax.set_title(title, size=size)
    ax.set_xlabel(xlabel, fontsize = font, labelpad = 10)
    ax.set_xticklabels(ax.get_xticklabels(), fontsize = fontsize, rotation = rotation)
    plt.tight_layout()
    plt.show()
    
f,ax = plt.subplots(1,2,figsize=(12,5))
value_count_plot(data=solar, col='year', sort=False, ascending=False, ax=ax[0], 
                 xlabel='year', title='Yearly Installation frequency', size= 16, fontsize=10, font=14, rotation=90)

cat_box_plot(x= 'year', y= 'size_kw_L', data=solar, ax=ax[1], xlabel='year', 
                     title='Year vs Size_kw_L', size=16, fontsize=10, font=14, rotation=90)

# %% [markdown]
# ♦ **Initial observation:** <br>
#
# → Overall, the number of installations have increased over the years. <br>
#
# → The size of the installations have also increased from the initial years (except 1999).

# %% [markdown]
# # `month`: installation month of solar panels

# %%
solar.pivot_table(index='month', columns='state', values='size_kw', aggfunc='size').style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_8d509708_8cab_11e9_8873_a86bad717d32row0_col0 {
#             background-color:  #d9ec66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row0_col1 {
#             background-color:  #e1f066;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row0_col2 {
#             background-color:  #d9ec66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row0_col3 {
#             background-color:  #f2f866;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row0_col4 {
#             background-color:  #bbdd66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row0_col5 {
#             background-color:  #73b966;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row0_col6 {
#             background-color:  #ffff66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row0_col7 {
#             background-color:  #d2e866;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row0_col8 {
#             background-color:  #d4ea66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row0_col9 {
#             background-color:  #ffff66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row0_col10 {
#             background-color:  #4ea666;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row0_col11 {
#             background-color:  #c8e366;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row1_col0 {
#             background-color:  #ffff66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row1_col1 {
#             background-color:  #ffff66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row1_col2 {
#             background-color:  #ffff66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row1_col3 {
#             background-color:  #ffff66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row1_col4 {
#             background-color:  #ffff66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row1_col5 {
#             background-color:  #ffff66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row1_col6 {
#             background-color:  #e1f066;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row1_col7 {
#             background-color:  #f1f866;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row1_col8 {
#             background-color:  #f2f866;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row1_col9 {
#             background-color:  #f9fc66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row1_col10 {
#             background-color:  #f2f866;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row1_col11 {
#             background-color:  #dbed66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row2_col0 {
#             background-color:  #dbed66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row2_col1 {
#             background-color:  #fefe66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row2_col2 {
#             background-color:  #deee66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row2_col3 {
#             background-color:  #c7e366;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row2_col4 {
#             background-color:  #aad466;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row2_col5 {
#             background-color:  #c0e066;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row2_col6 {
#             background-color:  #d3e966;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row2_col7 {
#             background-color:  #ffff66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row2_col8 {
#             background-color:  #c7e366;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row2_col9 {
#             background-color:  #e4f266;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row2_col10 {
#             background-color:  #ffff66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row2_col11 {
#             background-color:  #fcfe66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row3_col0 {
#             background-color:  #e3f166;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row3_col1 {
#             background-color:  #f8fc66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row3_col2 {
#             background-color:  #e0f066;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row3_col3 {
#             background-color:  #8ec666;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row3_col4 {
#             background-color:  #5faf66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row3_col5 {
#             background-color:  #8bc566;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row3_col6 {
#             background-color:  #d5ea66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row3_col7 {
#             background-color:  #fdfe66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row3_col8 {
#             background-color:  #bfdf66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row3_col9 {
#             background-color:  #c6e266;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row3_col10 {
#             background-color:  #d4ea66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row3_col11 {
#             background-color:  #eaf466;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row4_col0 {
#             background-color:  #cbe566;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row4_col1 {
#             background-color:  #deee66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row4_col2 {
#             background-color:  #dbed66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row4_col3 {
#             background-color:  #6eb666;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row4_col4 {
#             background-color:  #40a066;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row4_col5 {
#             background-color:  #c7e366;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row4_col6 {
#             background-color:  #d2e866;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row4_col7 {
#             background-color:  #b0d866;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row4_col8 {
#             background-color:  #d2e866;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row4_col9 {
#             background-color:  #cfe766;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row4_col10 {
#             background-color:  #9cce66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row4_col11 {
#             background-color:  #ffff66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row5_col0 {
#             background-color:  #cce666;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row5_col1 {
#             background-color:  #bcde66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row5_col2 {
#             background-color:  #a4d266;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row5_col3 {
#             background-color:  #60b066;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row5_col4 {
#             background-color:  #369b66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row5_col5 {
#             background-color:  #219066;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row5_col6 {
#             background-color:  #b7db66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row5_col7 {
#             background-color:  #c4e266;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row5_col8 {
#             background-color:  #daec66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row5_col9 {
#             background-color:  #5faf66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row5_col10 {
#             background-color:  #77bb66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row5_col11 {
#             background-color:  #bfdf66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row6_col0 {
#             background-color:  #b8dc66;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row6_col1 {
#             background-color:  #82c066;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row6_col2 {
#             background-color:  #8fc766;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row6_col3 {
#             background-color:  #2f9766;
#         }    #T_8d509708_8cab_11e9_8873_a86bad717d32row6_col4 {

# %%
f,ax = plt.subplots(figsize=(12,4))
solar_year = solar.groupby('month').agg({'size_kw':'median'})
solar_year.plot(ax=ax)

f,ax = plt.subplots(1,2,figsize=(12,5))
value_count_plot(data=solar, col='month', sort=False, ascending=False, ax=ax[0], 
                 xlabel='month', title='Monthly Installation frequency', size= 16, fontsize=10, font=14, rotation=90)

cat_box_plot(x= 'month', y= 'size_kw_L', data=solar, ax=ax[1], xlabel='month', 
                     title='Month vs Size_kw_L', size=16, fontsize=10, font=14, rotation=90)

# %% [markdown]
# ♦ **Initial observation:** <br>
#
# → The number of installations are generally higher during December. <br>
#
# → The size of solar panels installed is not affected by the month of installation.
#
# → When we explore statewide installation,  MA, MD, and NJ show a different trend that the rest of the states in the number of solar panel installations over different months.

# %% [markdown]
# # `state`

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series green.
    '''
    is_max = s == s.max()
    return ['background-color: green' if v else '' for v in is_max]

df.pivot_table(index='year', columns='state', values='size_kw', aggfunc='size', 
                               fill_value=0).style.apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_8df5478a_8cab_11e9_b261_a86bad717d32row11_col5 {
#             background-color:  green;
#         }    #T_8df5478a_8cab_11e9_b261_a86bad717d32row11_col10 {
#             background-color:  green;
#         }    #T_8df5478a_8cab_11e9_b261_a86bad717d32row13_col4 {
#             background-color:  green;
#         }    #T_8df5478a_8cab_11e9_b261_a86bad717d32row14_col6 {
#             background-color:  green;
#         }    #T_8df5478a_8cab_11e9_b261_a86bad717d32row16_col0 {
#             background-color:  green;
#         }    #T_8df5478a_8cab_11e9_b261_a86bad717d32row16_col1 {
#             background-color:  green;
#         }    #T_8df5478a_8cab_11e9_b261_a86bad717d32row16_col2 {
#             background-color:  green;
#         }    #T_8df5478a_8cab_11e9_b261_a86bad717d32row16_col3 {
#             background-color:  green;
#         }    #T_8df5478a_8cab_11e9_b261_a86bad717d32row16_col7 {
#             background-color:  green;
#         }    #T_8df5478a_8cab_11e9_b261_a86bad717d32row16_col8 {
#             background-color:  green;
#         }    #T_8df5478a_8cab_11e9_b261_a86bad717d32row16_col9 {
#             background-color:  green;
#         }    #T_8df5478a_8cab_11e9_b261_a86bad717d32row16_col11 {
#             background-color:  green;
#         }</style>
# <table id="T_8df5478a_8cab_11e9_b261_a86bad717d32" >
# <thead>    <tr>
#         <th class="index_name level0" >state</th>
#         <th class="col_heading level0 col0" >AZ</th>
#         <th class="col_heading level0 col1" >CA</th>
#         <th class="col_heading level0 col2" >CT</th>
#         <th class="col_heading level0 col3" >MA</th>
#         <th class="col_heading level0 col4" >MD</th>
#         <th class="col_heading level0 col5" >NJ</th>
#         <th class="col_heading level0 col6" >NM</th>
#         <th class="col_heading level0 col7" >NV</th>
#         <th class="col_heading level0 col8" >NY</th>
#         <th class="col_heading level0 col9" >Other</th>
#         <th class="col_heading level0 col10" >PA</th>
#         <th class="col_heading level0 col11" >TX</th>
#     </tr>    <tr>
#         <th class="index_name level0" >year</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_8df5478a_8cab_11e9_b261_a86bad717d32level0_row0" class="row_heading level0 row0" >1999</th>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row0_col0" class="data row0 col0" >792</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row0_col1" class="data row0 col1" >7</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row0_col2" class="data row0 col2" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row0_col3" class="data row0 col3" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row0_col4" class="data row0 col4" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row0_col5" class="data row0 col5" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row0_col6" class="data row0 col6" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row0_col7" class="data row0 col7" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row0_col8" class="data row0 col8" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row0_col9" class="data row0 col9" >5</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row0_col10" class="data row0 col10" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row0_col11" class="data row0 col11" >0</td>
#     </tr>    <tr>
#         <th id="T_8df5478a_8cab_11e9_b261_a86bad717d32level0_row1" class="row_heading level0 row1" >2000</th>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row1_col0" class="data row1 col0" >7</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row1_col1" class="data row1 col1" >5</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row1_col2" class="data row1 col2" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row1_col3" class="data row1 col3" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row1_col4" class="data row1 col4" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row1_col5" class="data row1 col5" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row1_col6" class="data row1 col6" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row1_col7" class="data row1 col7" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row1_col8" class="data row1 col8" >2</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row1_col9" class="data row1 col9" >25</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row1_col10" class="data row1 col10" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row1_col11" class="data row1 col11" >0</td>
#     </tr>    <tr>
#         <th id="T_8df5478a_8cab_11e9_b261_a86bad717d32level0_row2" class="row_heading level0 row2" >2001</th>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row2_col0" class="data row2 col0" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row2_col1" class="data row2 col1" >112</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row2_col2" class="data row2 col2" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row2_col3" class="data row2 col3" >1</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row2_col4" class="data row2 col4" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row2_col5" class="data row2 col5" >3</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row2_col6" class="data row2 col6" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row2_col7" class="data row2 col7" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row2_col8" class="data row2 col8" >8</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row2_col9" class="data row2 col9" >44</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row2_col10" class="data row2 col10" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row2_col11" class="data row2 col11" >4</td>
#     </tr>    <tr>
#         <th id="T_8df5478a_8cab_11e9_b261_a86bad717d32level0_row3" class="row_heading level0 row3" >2002</th>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row3_col0" class="data row3 col0" >21</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row3_col1" class="data row3 col1" >226</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row3_col2" class="data row3 col2" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row3_col3" class="data row3 col3" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row3_col4" class="data row3 col4" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row3_col5" class="data row3 col5" >19</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row3_col6" class="data row3 col6" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row3_col7" class="data row3 col7" >0</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row3_col8" class="data row3 col8" >137</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row3_col9" class="data row3 col9" >39</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row3_col10" class="data row3 col10" >6</td>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row3_col11" class="data row3 col11" >0</td>
#     </tr>    <tr>
#         <th id="T_8df5478a_8cab_11e9_b261_a86bad717d32level0_row4" class="row_heading level0 row4" >2003</th>
#         <td id="T_8df5478a_8cab_11e9_b261_a86bad717d32row4_col0" class="data row4 col0" >51</td>
#         <td id="T_8df54

# %%
f,ax = plt.subplots(1,2,figsize=(12,5))
value_count_plot(data=solar, col='state', sort=True, ascending=False, ax=ax[0], 
                 xlabel='State', title='State-wise Installation frequency', size= 16, fontsize=10, font=14, rotation=90)


cat_box_plot(x= 'state', y= 'size_kw_L', data=solar, ax=ax[1], xlabel='State', 
                     title='State vs Size_kw_L', size=16, fontsize=10, font=14, rotation=90)

# %% [markdown]
# ♦ **Initial observation:** <br>
#
# → Overall, the number of installations and the size of installations have increased over the years in different states.  <br>
#
# → Although CA has the most installations, the mean size of solar panel installation in CA is less than most of the states.

# %% [markdown]
# ## `zipcode_1`: 1st number from zipcode representing a larger area

# %%
solar.groupby('zipcode_1').agg({'size_kw':['mean', 'median', 'size']}).style.apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_8e64fcee_8cab_11e9_bd89_a86bad717d32row0_col0 {
#             background-color:  green;
#         }    #T_8e64fcee_8cab_11e9_bd89_a86bad717d32row4_col1 {
#             background-color:  green;
#         }    #T_8e64fcee_8cab_11e9_bd89_a86bad717d32row7_col2 {
#             background-color:  green;
#         }</style>
# <table id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" colspan=3>size_kw</th>
#     </tr>    <tr>
#         <th class="blank level1" ></th>
#         <th class="col_heading level1 col0" >mean</th>
#         <th class="col_heading level1 col1" >median</th>
#         <th class="col_heading level1 col2" >size</th>
#     </tr>    <tr>
#         <th class="index_name level0" >zipcode_1</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row0_col0" class="data row0 col0" >7.24428</td>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row0_col1" class="data row0 col1" >6.75</td>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row0_col2" class="data row0 col2" >63986</td>
#     </tr>    <tr>
#         <th id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row1_col0" class="data row1 col0" >6.52056</td>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row1_col1" class="data row1 col1" >5.886</td>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row1_col2" class="data row1 col2" >24687</td>
#     </tr>    <tr>
#         <th id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row2_col0" class="data row2 col0" >5.63348</td>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row2_col1" class="data row2 col1" >5.06</td>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row2_col2" class="data row2 col2" >3007</td>
#     </tr>    <tr>
#         <th id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32level0_row3" class="row_heading level0 row3" >5</th>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row3_col0" class="data row3 col0" >4.62784</td>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row3_col1" class="data row3 col1" >3.872</td>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row3_col2" class="data row3 col2" >1095</td>
#     </tr>    <tr>
#         <th id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32level0_row4" class="row_heading level0 row4" >6</th>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row4_col0" class="data row4 col0" >7.21913</td>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row4_col1" class="data row4 col1" >6.885</td>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row4_col2" class="data row4 col2" >11458</td>
#     </tr>    <tr>
#         <th id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32level0_row5" class="row_heading level0 row5" >7</th>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row5_col0" class="data row5 col0" >6.09908</td>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row5_col1" class="data row5 col1" >5.92</td>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row5_col2" class="data row5 col2" >5892</td>
#     </tr>    <tr>
#         <th id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32level0_row6" class="row_heading level0 row6" >8</th>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row6_col0" class="data row6 col0" >7.00077</td>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row6_col1" class="data row6 col1" >6.48</td>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row6_col2" class="data row6 col2" >68725</td>
#     </tr>    <tr>
#         <th id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32level0_row7" class="row_heading level0 row7" >9</th>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row7_col0" class="data row7 col0" >5.50923</td>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row7_col1" class="data row7 col1" >4.95</td>
#         <td id="T_8e64fcee_8cab_11e9_bd89_a86bad717d32row7_col2" class="data row7 col2" >210952</td>
#     </tr></tbody>
# </table>

# %%
df.pivot_table(index='zipcode_1', columns='year', values='size_kw', 
                       fill_value=0, aggfunc='size').style.apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col4 {
#             background-color:  green;
#         }    #T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col5 {
#             background-color:  green;
#         }    #T_8e8a45c6_8cab_11e9_959a_a86bad717d32row6_col0 {
#             background-color:  green;
#         }    #T_8e8a45c6_8cab_11e9_959a_a86bad717d32row6_col6 {
#             background-color:  green;
#         }    #T_8e8a45c6_8cab_11e9_959a_a86bad717d32row6_col7 {
#             background-color:  green;
#         }    #T_8e8a45c6_8cab_11e9_959a_a86bad717d32row7_col1 {
#             background-color:  green;
#         }    #T_8e8a45c6_8cab_11e9_959a_a86bad717d32row7_col2 {
#             background-color:  green;
#         }    #T_8e8a45c6_8cab_11e9_959a_a86bad717d32row7_col3 {
#             background-color:  green;
#         }    #T_8e8a45c6_8cab_11e9_959a_a86bad717d32row7_col8 {
#             background-color:  green;
#         }    #T_8e8a45c6_8cab_11e9_959a_a86bad717d32row7_col9 {
#             background-color:  green;
#         }    #T_8e8a45c6_8cab_11e9_959a_a86bad717d32row7_col10 {
#             background-color:  green;
#         }    #T_8e8a45c6_8cab_11e9_959a_a86bad717d32row7_col11 {
#             background-color:  green;
#         }    #T_8e8a45c6_8cab_11e9_959a_a86bad717d32row7_col12 {
#             background-color:  green;
#         }    #T_8e8a45c6_8cab_11e9_959a_a86bad717d32row7_col13 {
#             background-color:  green;
#         }    #T_8e8a45c6_8cab_11e9_959a_a86bad717d32row7_col14 {
#             background-color:  green;
#         }    #T_8e8a45c6_8cab_11e9_959a_a86bad717d32row7_col15 {
#             background-color:  green;
#         }    #T_8e8a45c6_8cab_11e9_959a_a86bad717d32row7_col16 {
#             background-color:  green;
#         }</style>
# <table id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32" >
# <thead>    <tr>
#         <th class="index_name level0" >year</th>
#         <th class="col_heading level0 col0" >1999</th>
#         <th class="col_heading level0 col1" >2000</th>
#         <th class="col_heading level0 col2" >2001</th>
#         <th class="col_heading level0 col3" >2002</th>
#         <th class="col_heading level0 col4" >2003</th>
#         <th class="col_heading level0 col5" >2004</th>
#         <th class="col_heading level0 col6" >2005</th>
#         <th class="col_heading level0 col7" >2006</th>
#         <th class="col_heading level0 col8" >2007</th>
#         <th class="col_heading level0 col9" >2008</th>
#         <th class="col_heading level0 col10" >2009</th>
#         <th class="col_heading level0 col11" >2010</th>
#         <th class="col_heading level0 col12" >2011</th>
#         <th class="col_heading level0 col13" >2012</th>
#         <th class="col_heading level0 col14" >2013</th>
#         <th class="col_heading level0 col15" >2014</th>
#         <th class="col_heading level0 col16" >2015</th>
#     </tr>    <tr>
#         <th class="index_name level0" >zipcode_1</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col0" class="data row0 col0" >0</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col1" class="data row0 col1" >2</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col2" class="data row0 col2" >9</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col3" class="data row0 col3" >143</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col4" class="data row0 col4" >181</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col5" class="data row0 col5" >212</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col6" class="data row0 col6" >248</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col7" class="data row0 col7" >441</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col8" class="data row0 col8" >642</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col9" class="data row0 col9" >869</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col10" class="data row0 col10" >1842</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col11" class="data row0 col11" >3880</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col12" class="data row0 col12" >3783</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col13" class="data row0 col13" >3993</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col14" class="data row0 col14" >6423</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col15" class="data row0 col15" >13136</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row0_col16" class="data row0 col16" >28182</td>
#     </tr>    <tr>
#         <th id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row1_col0" class="data row1 col0" >0</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row1_col1" class="data row1 col1" >0</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row1_col2" class="data row1 col2" >0</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row1_col3" class="data row1 col3" >0</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row1_col4" class="data row1 col4" >29</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row1_col5" class="data row1 col5" >50</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row1_col6" class="data row1 col6" >38</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row1_col7" class="data row1 col7" >90</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row1_col8" class="data row1 col8" >56</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row1_col9" class="data row1 col9" >216</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row1_col10" class="data row1 col10" >763</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row1_col11" class="data row1 col11" >686</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row1_col12" class="data row1 col12" >1031</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row1_col13" class="data row1 col13" >2059</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row1_col14" class="data row1 col14" >3033</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row1_col15" class="data row1 col15" >5203</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row1_col16" class="data row1 col16" >11433</td>
#     </tr>    <tr>
#         <th id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row2_col0" class="data row2 col0" >0</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row2_col1" class="data row2 col1" >0</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row2_col2" class="data row2 col2" >0</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row2_col3" class="data row2 col3" >1</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row2_col4" class="data row2 col4" >0</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row2_col5" class="data row2 col5" >0</td>
#         <td id="T_8e8a45c6_8cab_11e9_959a_a86bad717d32row2_col6" class="data row2 col6" >0</td>
#         <td id="T_8e8a4

# %%
f,ax = plt.subplots(figsize=(12,4))
solar_year = solar.groupby('zipcode_1').agg({'size_kw':'mean'})
solar_year.plot(ax=ax)

# %%
f,ax = plt.subplots(1,2,figsize=(12,5))

value_count_plot(data=solar, col='zipcode_1', sort=True, ascending=False, ax=ax[0], 
                 xlabel='Zipcode_1', title='Zipcode_1 (location) Installation frequency',size=16, fontsize=10, font=14, rotation=90)

cat_box_plot(x='zipcode_1', y='size_kw_L',data=solar, ax=ax[1], xlabel='Zipcode_1', 
                     title='Zipcode_1 vs Size_kw_L',size=16,fontsize=10, font=14, rotation=90)

# %% [markdown]
# ♦ **Initial observation:** <br>
#
# → Overall, zipcode (with 1st number) 9 has installed the most solar panels over the years. <br>
#
# → The size of the solar panels installed are lowest in the area of zipcode starting with 5.

# %% [markdown]
# # `Installer`: installing company for solar panels

# %%
solar.groupby('installer').agg({'size_kw':['mean', 'median', 'size']}).style.apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_8f165fee_8cab_11e9_838d_a86bad717d32row1_col2 {
#             background-color:  green;
#         }    #T_8f165fee_8cab_11e9_838d_a86bad717d32row8_col0 {
#             background-color:  green;
#         }    #T_8f165fee_8cab_11e9_838d_a86bad717d32row8_col1 {
#             background-color:  green;
#         }</style>
# <table id="T_8f165fee_8cab_11e9_838d_a86bad717d32" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" colspan=3>size_kw</th>
#     </tr>    <tr>
#         <th class="blank level1" ></th>
#         <th class="col_heading level1 col0" >mean</th>
#         <th class="col_heading level1 col1" >median</th>
#         <th class="col_heading level1 col2" >size</th>
#     </tr>    <tr>
#         <th class="index_name level0" >installer</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_8f165fee_8cab_11e9_838d_a86bad717d32level0_row0" class="row_heading level0 row0" >Grid Alternatives</th>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row0_col0" class="data row0 col0" >3.43341</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row0_col1" class="data row0 col1" >3.22</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row0_col2" class="data row0 col2" >4421</td>
#     </tr>    <tr>
#         <th id="T_8f165fee_8cab_11e9_838d_a86bad717d32level0_row1" class="row_heading level0 row1" >Other</th>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row1_col0" class="data row1 col0" >6.2934</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row1_col1" class="data row1 col1" >5.67</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row1_col2" class="data row1 col2" >179191</td>
#     </tr>    <tr>
#         <th id="T_8f165fee_8cab_11e9_838d_a86bad717d32level0_row2" class="row_heading level0 row2" >PetersenDean</th>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row2_col0" class="data row2 col0" >4.78601</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row2_col1" class="data row2 col1" >4.40806</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row2_col2" class="data row2 col2" >5504</td>
#     </tr>    <tr>
#         <th id="T_8f165fee_8cab_11e9_838d_a86bad717d32level0_row3" class="row_heading level0 row3" >RGS/Real Goods</th>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row3_col0" class="data row3 col0" >6.05306</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row3_col1" class="data row3 col1" >5.405</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row3_col2" class="data row3 col2" >6448</td>
#     </tr>    <tr>
#         <th id="T_8f165fee_8cab_11e9_838d_a86bad717d32level0_row4" class="row_heading level0 row4" >Rec Solar</th>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row4_col0" class="data row4 col0" >6.07808</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row4_col1" class="data row4 col1" >5.5</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row4_col2" class="data row4 col2" >8516</td>
#     </tr>    <tr>
#         <th id="T_8f165fee_8cab_11e9_838d_a86bad717d32level0_row5" class="row_heading level0 row5" >SolarCity</th>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row5_col0" class="data row5 col0" >6.24302</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row5_col1" class="data row5 col1" >5.72</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row5_col2" class="data row5 col2" >90439</td>
#     </tr>    <tr>
#         <th id="T_8f165fee_8cab_11e9_838d_a86bad717d32level0_row6" class="row_heading level0 row6" >Sungevity</th>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row6_col0" class="data row6 col0" >5.78511</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row6_col1" class="data row6 col1" >5.405</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row6_col2" class="data row6 col2" >7465</td>
#     </tr>    <tr>
#         <th id="T_8f165fee_8cab_11e9_838d_a86bad717d32level0_row7" class="row_heading level0 row7" >Sunpower</th>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row7_col0" class="data row7 col0" >2.49214</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row7_col1" class="data row7 col1" >2.205</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row7_col2" class="data row7 col2" >8963</td>
#     </tr>    <tr>
#         <th id="T_8f165fee_8cab_11e9_838d_a86bad717d32level0_row8" class="row_heading level0 row8" >Sunrun</th>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row8_col0" class="data row8 col0" >6.80612</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row8_col1" class="data row8 col1" >6.32</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row8_col2" class="data row8 col2" >4414</td>
#     </tr>    <tr>
#         <th id="T_8f165fee_8cab_11e9_838d_a86bad717d32level0_row9" class="row_heading level0 row9" >Unknown</th>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row9_col0" class="data row9 col0" >6.75744</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row9_col1" class="data row9 col1" >6.3</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row9_col2" class="data row9 col2" >49570</td>
#     </tr>    <tr>
#         <th id="T_8f165fee_8cab_11e9_838d_a86bad717d32level0_row10" class="row_heading level0 row10" >Verengo</th>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row10_col0" class="data row10 col0" >5.82305</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row10_col1" class="data row10 col1" >5.34286</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row10_col2" class="data row10 col2" >9477</td>
#     </tr>    <tr>
#         <th id="T_8f165fee_8cab_11e9_838d_a86bad717d32level0_row11" class="row_heading level0 row11" >Vivint</th>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row11_col0" class="data row11 col0" >6.37353</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row11_col1" class="data row11 col1" >5.7725</td>
#         <td id="T_8f165fee_8cab_11e9_838d_a86bad717d32row11_col2" class="data row11 col2" >15394</td>
#     </tr></tbody>
# </table>

# %%
f,ax = plt.subplots(1,2,figsize=(12,5))
value_count_plot(data=solar, col='installer', sort=True, ascending=False, ax=ax[0], 
                 xlabel='installer', title='Installer Installation frequency', size= 16, fontsize=10, font=14, rotation=90)


cat_box_plot(x= 'installer', y= 'size_kw_L', data=solar, ax=ax[1], xlabel='State', 
                     title='Installer vs Size_kw_L', size=16, fontsize=10, font=14, rotation=90)

# %% [markdown]
# ♦ **Initial observation:** <br>
#
# → There were several companies over all these states who are officially registered to install solar panels. But the installation companies that have installed less than 1% of the total solar panels are aggregated as `others`.   <br>
#
# → The largest solar panels are installed by a company `Sunrun`. The most installations are done by `Solarcity`.

# %% [markdown]
# # `Tech_1`: different types of solar panels

# %%
solar.groupby('tech_1').agg({'size_kw':['mean', 'median', 'size']}).style.apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_8f6f10fa_8cab_11e9_965d_a86bad717d32row2_col2 {
#             background-color:  green;
#         }    #T_8f6f10fa_8cab_11e9_965d_a86bad717d32row3_col1 {
#             background-color:  green;
#         }    #T_8f6f10fa_8cab_11e9_965d_a86bad717d32row4_col0 {
#             background-color:  green;
#         }</style>
# <table id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" colspan=3>size_kw</th>
#     </tr>    <tr>
#         <th class="blank level1" ></th>
#         <th class="col_heading level1 col0" >mean</th>
#         <th class="col_heading level1 col1" >median</th>
#         <th class="col_heading level1 col2" >size</th>
#     </tr>    <tr>
#         <th class="index_name level0" >tech_1</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32level0_row0" class="row_heading level0 row0" >Mono</th>
#         <td id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32row0_col0" class="data row0 col0" >6.00539</td>
#         <td id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32row0_col1" class="data row0 col1" >5.4</td>
#         <td id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32row0_col2" class="data row0 col2" >119181</td>
#     </tr>    <tr>
#         <th id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32level0_row1" class="row_heading level0 row1" >Other</th>
#         <td id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32row1_col0" class="data row1 col0" >5.93221</td>
#         <td id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32row1_col1" class="data row1 col1" >5.14117</td>
#         <td id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32row1_col2" class="data row1 col2" >4608</td>
#     </tr>    <tr>
#         <th id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32level0_row2" class="row_heading level0 row2" >Poly</th>
#         <td id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32row2_col0" class="data row2 col0" >6.03933</td>
#         <td id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32row2_col1" class="data row2 col1" >5.5</td>
#         <td id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32row2_col2" class="data row2 col2" >175819</td>
#     </tr>    <tr>
#         <th id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32level0_row3" class="row_heading level0 row3" >Unknown</th>
#         <td id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32row3_col0" class="data row3 col0" >6.68576</td>
#         <td id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32row3_col1" class="data row3 col1" >6.21</td>
#         <td id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32row3_col2" class="data row3 col2" >85576</td>
#     </tr>    <tr>
#         <th id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32level0_row4" class="row_heading level0 row4" >crystalline</th>
#         <td id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32row4_col0" class="data row4 col0" >6.80875</td>
#         <td id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32row4_col1" class="data row4 col1" >6.12</td>
#         <td id="T_8f6f10fa_8cab_11e9_965d_a86bad717d32row4_col2" class="data row4 col2" >4618</td>
#     </tr></tbody>
# </table>

# %%
df.pivot_table(index='tech_1', columns='year', values='size_kw', 
                       fill_value=0, aggfunc='size').style.apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col11 {
#             background-color:  green;
#         }    #T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col12 {
#             background-color:  green;
#         }    #T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col13 {
#             background-color:  green;
#         }    #T_8f83b04c_8cab_11e9_8791_a86bad717d32row2_col8 {
#             background-color:  green;
#         }    #T_8f83b04c_8cab_11e9_8791_a86bad717d32row2_col9 {
#             background-color:  green;
#         }    #T_8f83b04c_8cab_11e9_8791_a86bad717d32row2_col10 {
#             background-color:  green;
#         }    #T_8f83b04c_8cab_11e9_8791_a86bad717d32row2_col14 {
#             background-color:  green;
#         }    #T_8f83b04c_8cab_11e9_8791_a86bad717d32row2_col15 {
#             background-color:  green;
#         }    #T_8f83b04c_8cab_11e9_8791_a86bad717d32row2_col16 {
#             background-color:  green;
#         }    #T_8f83b04c_8cab_11e9_8791_a86bad717d32row3_col0 {
#             background-color:  green;
#         }    #T_8f83b04c_8cab_11e9_8791_a86bad717d32row3_col1 {
#             background-color:  green;
#         }    #T_8f83b04c_8cab_11e9_8791_a86bad717d32row3_col2 {
#             background-color:  green;
#         }    #T_8f83b04c_8cab_11e9_8791_a86bad717d32row3_col3 {
#             background-color:  green;
#         }    #T_8f83b04c_8cab_11e9_8791_a86bad717d32row3_col4 {
#             background-color:  green;
#         }    #T_8f83b04c_8cab_11e9_8791_a86bad717d32row3_col5 {
#             background-color:  green;
#         }    #T_8f83b04c_8cab_11e9_8791_a86bad717d32row3_col6 {
#             background-color:  green;
#         }    #T_8f83b04c_8cab_11e9_8791_a86bad717d32row3_col7 {
#             background-color:  green;
#         }</style>
# <table id="T_8f83b04c_8cab_11e9_8791_a86bad717d32" >
# <thead>    <tr>
#         <th class="index_name level0" >year</th>
#         <th class="col_heading level0 col0" >1999</th>
#         <th class="col_heading level0 col1" >2000</th>
#         <th class="col_heading level0 col2" >2001</th>
#         <th class="col_heading level0 col3" >2002</th>
#         <th class="col_heading level0 col4" >2003</th>
#         <th class="col_heading level0 col5" >2004</th>
#         <th class="col_heading level0 col6" >2005</th>
#         <th class="col_heading level0 col7" >2006</th>
#         <th class="col_heading level0 col8" >2007</th>
#         <th class="col_heading level0 col9" >2008</th>
#         <th class="col_heading level0 col10" >2009</th>
#         <th class="col_heading level0 col11" >2010</th>
#         <th class="col_heading level0 col12" >2011</th>
#         <th class="col_heading level0 col13" >2012</th>
#         <th class="col_heading level0 col14" >2013</th>
#         <th class="col_heading level0 col15" >2014</th>
#         <th class="col_heading level0 col16" >2015</th>
#     </tr>    <tr>
#         <th class="index_name level0" >tech_1</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_8f83b04c_8cab_11e9_8791_a86bad717d32level0_row0" class="row_heading level0 row0" >Mono</th>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col0" class="data row0 col0" >2</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col1" class="data row0 col1" >0</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col2" class="data row0 col2" >3</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col3" class="data row0 col3" >0</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col4" class="data row0 col4" >2</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col5" class="data row0 col5" >52</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col6" class="data row0 col6" >98</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col7" class="data row0 col7" >134</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col8" class="data row0 col8" >1200</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col9" class="data row0 col9" >2989</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col10" class="data row0 col10" >6365</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col11" class="data row0 col11" >10763</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col12" class="data row0 col12" >13229</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col13" class="data row0 col13" >18009</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col14" class="data row0 col14" >17608</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col15" class="data row0 col15" >12200</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row0_col16" class="data row0 col16" >36527</td>
#     </tr>    <tr>
#         <th id="T_8f83b04c_8cab_11e9_8791_a86bad717d32level0_row1" class="row_heading level0 row1" >Other</th>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row1_col0" class="data row1 col0" >0</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row1_col1" class="data row1 col1" >0</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row1_col2" class="data row1 col2" >0</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row1_col3" class="data row1 col3" >0</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row1_col4" class="data row1 col4" >0</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row1_col5" class="data row1 col5" >2</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row1_col6" class="data row1 col6" >50</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row1_col7" class="data row1 col7" >57</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row1_col8" class="data row1 col8" >342</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row1_col9" class="data row1 col9" >554</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row1_col10" class="data row1 col10" >1272</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row1_col11" class="data row1 col11" >958</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row1_col12" class="data row1 col12" >565</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row1_col13" class="data row1 col13" >232</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row1_col14" class="data row1 col14" >87</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row1_col15" class="data row1 col15" >32</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row1_col16" class="data row1 col16" >457</td>
#     </tr>    <tr>
#         <th id="T_8f83b04c_8cab_11e9_8791_a86bad717d32level0_row2" class="row_heading level0 row2" >Poly</th>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row2_col0" class="data row2 col0" >0</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row2_col1" class="data row2 col1" >0</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row2_col2" class="data row2 col2" >2</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row2_col3" class="data row2 col3" >7</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row2_col4" class="data row2 col4" >25</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row2_col5" class="data row2 col5" >90</td>
#         <td id="T_8f83b04c_8cab_11e9_8791_a86bad717d32row2_col6" class="data row2 col6" >158</td>
#         <td id="T_8f

# %%
f,ax = plt.subplots(1,2,figsize=(12,5))
value_count_plot(data=solar, col='tech_1', sort=True, ascending=False, ax=ax[0], 
                 xlabel='tech_1', title='Tech_1 Installation frequency', size= 16, fontsize=10, font=14, rotation=90)


cat_box_plot(x= 'tech_1', y= 'size_kw_L', data=solar, ax=ax[1], xlabel='State', 
                     title='Tech_1 vs Size_kw_L', size=16, fontsize=10, font=14, rotation=90)

# %% [markdown]
# ♦ **Initial observation:** <br>
#
# → The most popular solar panels used for residential setting are `Poly`.  <br>

# %% [markdown]
# # `county` county where solar panel has been installed

# %%
pd.options.display.max_columns = 25
solar.groupby('county').agg({'size_kw':['mean', 'median', 'size']}).round(2).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row0_col0 {
#             background-color:  #ffff66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row0_col1 {
#             background-color:  #ffff66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row0_col2 {
#             background-color:  #fbfd66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row1_col0 {
#             background-color:  #1d8e66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row1_col1 {
#             background-color:  #219066;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row1_col2 {
#             background-color:  #ffff66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row2_col0 {
#             background-color:  #3e9e66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row2_col1 {
#             background-color:  #44a266;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row2_col2 {
#             background-color:  #f4fa66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row3_col0 {
#             background-color:  #bfdf66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row3_col1 {
#             background-color:  #b3d966;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row3_col2 {
#             background-color:  #f9fc66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row4_col0 {
#             background-color:  #56ab66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row4_col1 {
#             background-color:  #56ab66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row4_col2 {
#             background-color:  #fdfe66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row5_col0 {
#             background-color:  #6fb766;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row5_col1 {
#             background-color:  #6ab466;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row5_col2 {
#             background-color:  #f9fc66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row6_col0 {
#             background-color:  #7cbe66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row6_col1 {
#             background-color:  #7fbf66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row6_col2 {
#             background-color:  #f9fc66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row7_col0 {
#             background-color:  #c3e166;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row7_col1 {
#             background-color:  #c4e266;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row7_col2 {
#             background-color:  #b9dc66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row8_col0 {
#             background-color:  #038166;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row8_col1 {
#             background-color:  #0c8666;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row8_col2 {
#             background-color:  #c4e266;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row9_col0 {
#             background-color:  #51a866;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row9_col1 {
#             background-color:  #56ab66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row9_col2 {
#             background-color:  #eef666;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row10_col0 {
#             background-color:  #1e8e66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row10_col1 {
#             background-color:  #168b66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row10_col2 {
#             background-color:  #ffff66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row11_col0 {
#             background-color:  #3e9e66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row11_col1 {
#             background-color:  #4ca666;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row11_col2 {
#             background-color:  #ffff66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row12_col0 {
#             background-color:  #a2d066;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row12_col1 {
#             background-color:  #9bcd66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row12_col2 {
#             background-color:  #e7f366;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row13_col0 {
#             background-color:  #70b866;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row13_col1 {
#             background-color:  #76bb66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row13_col2 {
#             background-color:  #008066;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row14_col0 {
#             background-color:  #369b66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row14_col1 {
#             background-color:  #2c9666;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row14_col2 {
#             background-color:  #f4fa66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row15_col0 {
#             background-color:  #94ca66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row15_col1 {
#             background-color:  #93c966;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row15_col2 {
#             background-color:  #dcee66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row16_col0 {
#             background-color:  #bede66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row16_col1 {
#             background-color:  #b9dc66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row16_col2 {
#             background-color:  #fbfd66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row17_col0 {
#             background-color:  #aad466;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row17_col1 {
#             background-color:  #9fcf66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row17_col2 {
#             background-color:  #ecf666;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row18_col0 {
#             background-color:  #8fc766;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row18_col1 {
#             background-color:  #8cc666;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row18_col2 {
#             background-color:  #cbe566;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row19_col0 {
#             background-color:  #d8ec66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row19_col1 {
#             background-color:  #daec66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row19_col2 {
#             background-color:  #f2f866;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row20_col0 {
#             background-color:  #198c66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row20_col1 {
#             background-color:  #0b8566;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row20_col2 {
#             background-color:  #f0f866;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row21_col0 {
#             background-color:  #a5d266;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row21_col1 {
#             background-color:  #a0d066;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row21_col2 {
#             background-color:  #fdfe66;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row22_col0 {
#             background-color:  #008066;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row22_col1 {
#             background-color:  #008066;
#         }    #T_8fdda08a_8cab_11e9_91f9_a86bad717d32row22_col2 {
#             background-color:  #f8fc66;
#         }</style>
# <table id="T_8fdda08a_8cab_11e9_91f9_a86bad717d32" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" colspan=3>size_kw</th>
#     </tr>    <tr>
#         <th class="blank level1" ></th>
#         <th class="col_heading level1 col0" >mean</th>
#         <th class="col_heading level1 col1" >median</th>
#         <th class="col_heading level1 col2" >size</th>
#     </tr>    <tr>
#         <th class="index_name level0" >county</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_8fdda08a_8cab_11e9_91f9_a86bad717d32level0_row0" class="row_heading level0 row0" >Alameda</th>
#         <td id=

# %%
df.pivot_table(index='county', columns='year', values='size_kw', aggfunc='mean', 
                               fill_value=0).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_900bf95a_8cab_11e9_9027_a86bad717d32row0_col0 {
#             background-color:  #cae466;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row0_col1 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row0_col2 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row0_col3 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row0_col4 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row0_col5 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row0_col6 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row0_col7 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row0_col8 {
#             background-color:  #9acc66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row0_col9 {
#             background-color:  #d6eb66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row0_col10 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row0_col11 {
#             background-color:  #e2f066;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row0_col12 {
#             background-color:  #d0e866;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row0_col13 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row0_col14 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row0_col15 {
#             background-color:  #f3f966;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row0_col16 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row1_col0 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row1_col1 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row1_col2 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row1_col3 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row1_col4 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row1_col5 {
#             background-color:  #1e8e66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row1_col6 {
#             background-color:  #74ba66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row1_col7 {
#             background-color:  #82c066;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row1_col8 {
#             background-color:  #d1e866;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row1_col9 {
#             background-color:  #e6f266;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row1_col10 {
#             background-color:  #f7fb66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row1_col11 {
#             background-color:  #77bb66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row1_col12 {
#             background-color:  #7bbd66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row1_col13 {
#             background-color:  #0a8466;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row1_col14 {
#             background-color:  #5aac66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row1_col15 {
#             background-color:  #399c66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row1_col16 {
#             background-color:  #4ca666;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row2_col0 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row2_col1 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row2_col2 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row2_col3 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row2_col4 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row2_col5 {
#             background-color:  #4fa766;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row2_col6 {
#             background-color:  #61b066;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row2_col7 {
#             background-color:  #369b66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row2_col8 {
#             background-color:  #5dae66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row2_col9 {
#             background-color:  #6ab466;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row2_col10 {
#             background-color:  #90c866;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row2_col11 {
#             background-color:  #078366;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row2_col12 {
#             background-color:  #008066;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row2_col13 {
#             background-color:  #138966;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row2_col14 {
#             background-color:  #0b8566;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row2_col15 {
#             background-color:  #64b266;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row2_col16 {
#             background-color:  #67b366;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row3_col0 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row3_col1 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row3_col2 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row3_col3 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row3_col4 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row3_col5 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row3_col6 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row3_col7 {
#             background-color:  #bdde66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row3_col8 {
#             background-color:  #82c066;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row3_col9 {
#             background-color:  #cce666;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row3_col10 {
#             background-color:  #e2f066;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row3_col11 {
#             background-color:  #a0d066;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row3_col12 {
#             background-color:  #b1d866;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row3_col13 {
#             background-color:  #b7db66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row3_col14 {
#             background-color:  #bbdd66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row3_col15 {
#             background-color:  #c0e066;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row3_col16 {
#             background-color:  #c1e066;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row4_col0 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row4_col1 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row4_col2 {
#             background-color:  #ffff66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row4_col3 {
#             background-color:  #97cb66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row4_col4 {
#             background-color:  #9bcd66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row4_col5 {
#             background-color:  #3a9c66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row4_col6 {
#             background-color:  #309866;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d32row4_col7 {
#             background-color:  #399c66;
#         }    #T_900bf95a_8cab_11e9_9027_a86bad717d3

# %%
f,ax = plt.subplots(1,2,figsize=(12,5))

value_count_plot(data=solar, col='county', sort=True, ascending=False, ax=ax[0], 
                 xlabel='county', title='County-wise Installation frequency', size= 16, fontsize=10, font=14, rotation=90)


cat_box_plot(x= 'county', y= 'size_kw_L', data=solar, ax=ax[1], xlabel='State', 
                     title='County vs Size_kw_L', size=16, fontsize=10, font=14, rotation=90)

# %% [markdown]
# ♦ **Initial observation:** <br>
#
# → Counties that have contributed less than 1% of solar panel installations are aggregated as `others`.
#
# → LA and Maricopa have installed the most solar panels. <br>
#
# → Although solar panels have been popular early on in certain counties such as LA, San Diego, Santa Clara (basically CA),
# overall adoption has increased since 2004-2005 in various other counties.

# %% [markdown]
# ## `incentive_prog_names`: incentive programs for solar panel installation

# %%
pd.options.display.max_columns = 25
incentive_prog_names = solar.groupby('incentive_prog_names').agg({'size_kw':['mean', 'median', 'size']})
incentive_prog_names.columns = ['size_mean', 'size_median', 'size_number']
incentive_prog_names.sort_values(by='size_number', ascending=False).style.apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_9089ec46_8cab_11e9_a3f7_a86bad717d32row0_col2 {
#             background-color:  green;
#         }    #T_9089ec46_8cab_11e9_a3f7_a86bad717d32row14_col1 {
#             background-color:  green;
#         }    #T_9089ec46_8cab_11e9_a3f7_a86bad717d32row15_col0 {
#             background-color:  green;
#         }</style>
# <table id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >size_mean</th>
#         <th class="col_heading level0 col1" >size_median</th>
#         <th class="col_heading level0 col2" >size_number</th>
#     </tr>    <tr>
#         <th class="index_name level0" >incentive_prog_names</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32level0_row0" class="row_heading level0 row0" >California Public Utilities Commission (California Solar Initiative)</th>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row0_col0" class="data row0 col0" >5.77373</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row0_col1" class="data row0 col1" >5.17</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row0_col2" class="data row0 col2" >112684</td>
#     </tr>    <tr>
#         <th id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32level0_row1" class="row_heading level0 row1" >California Public Utilities Commission (Non-CSI Net Metered Systems)</th>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row1_col0" class="data row1 col0" >5.59563</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row1_col1" class="data row1 col1" >5.1238</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row1_col2" class="data row1 col2" >62280</td>
#     </tr>    <tr>
#         <th id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32level0_row2" class="row_heading level0 row2" >New York State Energy Research and Development Authority</th>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row2_col0" class="data row2 col0" >7.43806</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row2_col1" class="data row2 col1" >6.96</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row2_col2" class="data row2 col2" >32021</td>
#     </tr>    <tr>
#         <th id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32level0_row3" class="row_heading level0 row3" >Arizona Public Service</th>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row3_col0" class="data row3 col0" >7.16327</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row3_col1" class="data row3 col1" >6.72</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row3_col2" class="data row3 col2" >27670</td>
#     </tr>    <tr>
#         <th id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32level0_row4" class="row_heading level0 row4" >Massachusetts Clean Energy Center</th>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row4_col0" class="data row4 col0" >6.5715</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row4_col1" class="data row4 col1" >6</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row4_col2" class="data row4 col2" >26482</td>
#     </tr>    <tr>
#         <th id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32level0_row5" class="row_heading level0 row5" >Massachusetts Department of Energy Resources</th>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row5_col0" class="data row5 col0" >7.09861</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row5_col1" class="data row5 col1" >6.5</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row5_col2" class="data row5 col2" >18157</td>
#     </tr>    <tr>
#         <th id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32level0_row6" class="row_heading level0 row6" >Other</th>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row6_col0" class="data row6 col0" >5.59428</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row6_col1" class="data row6 col1" >5.1</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row6_col2" class="data row6 col2" >15556</td>
#     </tr>    <tr>
#         <th id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32level0_row7" class="row_heading level0 row7" >Los Angeles Department of Water & Power</th>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row7_col0" class="data row7 col0" >5.45507</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row7_col1" class="data row7 col1" >4.83</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row7_col2" class="data row7 col2" >14210</td>
#     </tr>    <tr>
#         <th id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32level0_row8" class="row_heading level0 row8" >California Energy Commission (New Solar Homes Partnership)</th>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row8_col0" class="data row8 col0" >3.19693</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row8_col1" class="data row8 col1" >2.4</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row8_col2" class="data row8 col2" >13379</td>
#     </tr>    <tr>
#         <th id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32level0_row9" class="row_heading level0 row9" >Salt River Project</th>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row9_col0" class="data row9 col0" >7.49978</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row9_col1" class="data row9 col1" >6.72</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row9_col2" class="data row9 col2" >11615</td>
#     </tr>    <tr>
#         <th id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32level0_row10" class="row_heading level0 row10" >Connecticut Clean Energy Finance and Investment Authority</th>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row10_col0" class="data row10 col0" >7.21913</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row10_col1" class="data row10 col1" >6.885</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row10_col2" class="data row10 col2" >11458</td>
#     </tr>    <tr>
#         <th id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32level0_row11" class="row_heading level0 row11" >NV Energy</th>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row11_col0" class="data row11 col0" >6.66532</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row11_col1" class="data row11 col1" >6.095</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row11_col2" class="data row11 col2" >10668</td>
#     </tr>    <tr>
#         <th id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32level0_row12" class="row_heading level0 row12" >Tucson Electric Power</th>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row12_col0" class="data row12 col0" >6.93163</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row12_col1" class="data row12 col1" >6.5</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row12_col2" class="data row12 col2" >8573</td>
#     </tr>    <tr>
#         <th id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32level0_row13" class="row_heading level0 row13" >Sacramento Municipal Utility District</th>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row13_col0" class="data row13 col0" >5.33773</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row13_col1" class="data row13 col1" >4.845</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row13_col2" class="data row13 col2" >6115</td>
#     </tr>    <tr>
#         <th id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32level0_row14" class="row_heading level0 row14" >New Jersey Board of Public Utilities (CORE & REIP Programs)</th>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row14_col0" class="data row14 col0" >7.54142</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row14_col1" class="data row14 col1" >7.59</td>
#         <td id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32row14_col2" class="data row14 col2" >5215</td>
#     </tr>    <tr>
#         <th id="T_9089ec46_8cab_11e9_a3f7_a86bad717d32

# %%
f,ax = plt.subplots(1,2,figsize=(12,5))
# Long names, make plots ugly
plt.setp(ax[0].get_xticklabels(), visible=False)
plt.setp(ax[1].get_xticklabels(), visible=False)

value_count_plot(data=solar, col='incentive_prog_names', sort=True, ascending=False, ax=ax[0], 
                 xlabel='incentive_prog_names', title='Incentive_prog Installation frequency', size= 16, fontsize=10, font=14, rotation=90)

cat_box_plot(x= 'incentive_prog_names', y= 'size_kw_L', data=solar, ax=ax[1], xlabel='incentive_prog_names', 
                     title='Incentive_prog vs Size_kw_L', size=16, fontsize=10, font=14, rotation=90)

# %% [markdown]
# ♦ **Initial observation:** <br>
#
# → Similar to counties, any incentive programs that have been used in less than 1% of solar panel installations are aggregated as `others`.
#
# → The most active incentive programs are in CA, as CA was one of the early adopters of clean energy or solar panels.

# %% [markdown]
# ## `city`: city of installation

# %%
solar.groupby('city').agg({'annual_PV_prod':['mean', 'median', 'size']}).style.apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_90ea9006_8cab_11e9_b1c1_a86bad717d32row2_col2 {
#             background-color:  green;
#         }    #T_90ea9006_8cab_11e9_b1c1_a86bad717d32row3_col0 {
#             background-color:  green;
#         }    #T_90ea9006_8cab_11e9_b1c1_a86bad717d32row3_col1 {
#             background-color:  green;
#         }</style>
# <table id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" colspan=3>annual_PV_prod</th>
#     </tr>    <tr>
#         <th class="blank level1" ></th>
#         <th class="col_heading level1 col0" >mean</th>
#         <th class="col_heading level1 col1" >median</th>
#         <th class="col_heading level1 col2" >size</th>
#     </tr>    <tr>
#         <th class="index_name level0" >city</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32level0_row0" class="row_heading level0 row0" >Las Vegas</th>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row0_col0" class="data row0 col0" >11417.7</td>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row0_col1" class="data row0 col1" >10366.2</td>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row0_col2" class="data row0 col2" >5923</td>
#     </tr>    <tr>
#         <th id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32level0_row1" class="row_heading level0 row1" >Los Angeles</th>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row1_col0" class="data row1 col0" >7037.55</td>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row1_col1" class="data row1 col1" >6041.02</td>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row1_col2" class="data row1 col2" >4862</td>
#     </tr>    <tr>
#         <th id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32level0_row2" class="row_heading level0 row2" >Other</th>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row2_col0" class="data row2 col0" >8937.98</td>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row2_col1" class="data row2 col1" >8059.31</td>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row2_col2" class="data row2 col2" >354837</td>
#     </tr>    <tr>
#         <th id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32level0_row3" class="row_heading level0 row3" >PHOENIX</th>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row3_col0" class="data row3 col0" >12343.3</td>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row3_col1" class="data row3 col1" >11486.5</td>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row3_col2" class="data row3 col2" >6912</td>
#     </tr>    <tr>
#         <th id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32level0_row4" class="row_heading level0 row4" >SAN DIEGO</th>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row4_col0" class="data row4 col0" >8596.92</td>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row4_col1" class="data row4 col1" >7754.73</td>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row4_col2" class="data row4 col2" >4606</td>
#     </tr>    <tr>
#         <th id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32level0_row5" class="row_heading level0 row5" >San Diego</th>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row5_col0" class="data row5 col0" >7644.92</td>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row5_col1" class="data row5 col1" >7064.65</td>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row5_col2" class="data row5 col2" >4926</td>
#     </tr>    <tr>
#         <th id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32level0_row6" class="row_heading level0 row6" >TUCSON</th>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row6_col0" class="data row6 col0" >12343.2</td>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row6_col1" class="data row6 col1" >11465.2</td>
#         <td id="T_90ea9006_8cab_11e9_b1c1_a86bad717d32row6_col2" class="data row6 col2" >7736</td>
#     </tr></tbody>
# </table>

# %%
f,ax = plt.subplots(1,2,figsize=(12,5))
# using solar_x data as 'others' will take over
solar_x_city = solar_x.groupby('city').agg({'size_kw':['mean', 'median', 'size']})
solar_x_city.columns = ['size_mean', 'size_median', 'total']
solar_x_city = solar_x_city.sort_values(by = 'total', ascending=False)
solar_x_city = solar_x_city.iloc[:15]
solar_x_city['total'].plot(kind='bar', ax=ax[0])

cat_box_plot(x= 'city', y= 'size_kw_L', data=solar, ax=ax[1], xlabel='City', 
                     title='City vs Size_kw_L', size=16, fontsize=10, font=14, rotation=90)

# %%
f,ax = plt.subplots(figsize=(10,4))
solar_x_city = solar_x.groupby('city').agg({'annual_PV_prod':['mean', 'median', 'size']})
solar_x_city.columns = ['size_mean', 'size_median', 'total']
solar_x_city = solar_x_city.sort_values(by = 'size_mean', ascending=False)
solar_x_city = solar_x_city.iloc[:15]
solar_x_city['size_mean'].plot(kind='bar')
ax.set_title('City vs Annual Solar Energy Production')
# Out:
# Text(0.5,1,'City vs Annual Solar Energy Production')

# %% [markdown]
# ♦ **Initial observation:** <br>
#
# → Similar to counties, any cities that had installed less than 1% of solar panels are aggregated as `others`.
#
# → The city of Phoenix has installed solar panels with highest `size_kw`.
#
# → The number of installations are highest in Arizona and CA.
#
# → Cities having the most solar panel installations does NOT mean they produce maximum solar energy. This could be due to various factors. Cities can install more solar panels but with relatively smaller sizes. Or cities with less insolation will produce less solar energy w.r.t. to the city that get more insolation even if they have similar installations.

# %% [markdown]
# ## `Tracking type`: impacts the efficiency of solar energy production

# %%
solar.groupby('tracking_type').agg({'size_kw':['mean', 'median', 'size']}).style.apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_9177b752_8cab_11e9_af27_a86bad717d32row0_col2 {
#             background-color:  green;
#         }    #T_9177b752_8cab_11e9_af27_a86bad717d32row1_col0 {
#             background-color:  green;
#         }    #T_9177b752_8cab_11e9_af27_a86bad717d32row1_col1 {
#             background-color:  green;
#         }</style>
# <table id="T_9177b752_8cab_11e9_af27_a86bad717d32" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" colspan=3>size_kw</th>
#     </tr>    <tr>
#         <th class="blank level1" ></th>
#         <th class="col_heading level1 col0" >mean</th>
#         <th class="col_heading level1 col1" >median</th>
#         <th class="col_heading level1 col2" >size</th>
#     </tr>    <tr>
#         <th class="index_name level0" >tracking_type</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_9177b752_8cab_11e9_af27_a86bad717d32level0_row0" class="row_heading level0 row0" >Fixed</th>
#         <td id="T_9177b752_8cab_11e9_af27_a86bad717d32row0_col0" class="data row0 col0" >6.05721</td>
#         <td id="T_9177b752_8cab_11e9_af27_a86bad717d32row0_col1" class="data row0 col1" >5.5</td>
#         <td id="T_9177b752_8cab_11e9_af27_a86bad717d32row0_col2" class="data row0 col2" >273985</td>
#     </tr>    <tr>
#         <th id="T_9177b752_8cab_11e9_af27_a86bad717d32level0_row1" class="row_heading level0 row1" >Other</th>
#         <td id="T_9177b752_8cab_11e9_af27_a86bad717d32row1_col0" class="data row1 col0" >6.75375</td>
#         <td id="T_9177b752_8cab_11e9_af27_a86bad717d32row1_col1" class="data row1 col1" >6</td>
#         <td id="T_9177b752_8cab_11e9_af27_a86bad717d32row1_col2" class="data row1 col2" >965</td>
#     </tr>    <tr>
#         <th id="T_9177b752_8cab_11e9_af27_a86bad717d32level0_row2" class="row_heading level0 row2" >Unknown</th>
#         <td id="T_9177b752_8cab_11e9_af27_a86bad717d32row2_col0" class="data row2 col0" >6.46375</td>
#         <td id="T_9177b752_8cab_11e9_af27_a86bad717d32row2_col1" class="data row2 col1" >5.94</td>
#         <td id="T_9177b752_8cab_11e9_af27_a86bad717d32row2_col2" class="data row2 col2" >114852</td>
#     </tr></tbody>
# </table>

# %%
solar.groupby('tracking_type').agg({'annual_PV_prod':['mean', 'median', 'size']}).style.apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_9184cdba_8cab_11e9_ba76_a86bad717d32row0_col2 {
#             background-color:  green;
#         }    #T_9184cdba_8cab_11e9_ba76_a86bad717d32row2_col0 {
#             background-color:  green;
#         }    #T_9184cdba_8cab_11e9_ba76_a86bad717d32row2_col1 {
#             background-color:  green;
#         }</style>
# <table id="T_9184cdba_8cab_11e9_ba76_a86bad717d32" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" colspan=3>annual_PV_prod</th>
#     </tr>    <tr>
#         <th class="blank level1" ></th>
#         <th class="col_heading level1 col0" >mean</th>
#         <th class="col_heading level1 col1" >median</th>
#         <th class="col_heading level1 col2" >size</th>
#     </tr>    <tr>
#         <th class="index_name level0" >tracking_type</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_9184cdba_8cab_11e9_ba76_a86bad717d32level0_row0" class="row_heading level0 row0" >Fixed</th>
#         <td id="T_9184cdba_8cab_11e9_ba76_a86bad717d32row0_col0" class="data row0 col0" >8728.99</td>
#         <td id="T_9184cdba_8cab_11e9_ba76_a86bad717d32row0_col1" class="data row0 col1" >7905.41</td>
#         <td id="T_9184cdba_8cab_11e9_ba76_a86bad717d32row0_col2" class="data row0 col2" >273985</td>
#     </tr>    <tr>
#         <th id="T_9184cdba_8cab_11e9_ba76_a86bad717d32level0_row1" class="row_heading level0 row1" >Other</th>
#         <td id="T_9184cdba_8cab_11e9_ba76_a86bad717d32row1_col0" class="data row1 col0" >9337.61</td>
#         <td id="T_9184cdba_8cab_11e9_ba76_a86bad717d32row1_col1" class="data row1 col1" >8304.87</td>
#         <td id="T_9184cdba_8cab_11e9_ba76_a86bad717d32row1_col2" class="data row1 col2" >965</td>
#     </tr>    <tr>
#         <th id="T_9184cdba_8cab_11e9_ba76_a86bad717d32level0_row2" class="row_heading level0 row2" >Unknown</th>
#         <td id="T_9184cdba_8cab_11e9_ba76_a86bad717d32row2_col0" class="data row2 col0" >9845.77</td>
#         <td id="T_9184cdba_8cab_11e9_ba76_a86bad717d32row2_col1" class="data row2 col1" >8837.11</td>
#         <td id="T_9184cdba_8cab_11e9_ba76_a86bad717d32row2_col2" class="data row2 col2" >114852</td>
#     </tr></tbody>
# </table>

# %%
f,ax = plt.subplots(1,2,figsize=(12,5))

value_count_plot(data=solar, col='tracking_type', sort=True, ascending=False, ax=ax[0], 
                 xlabel='Tracking_type', title='Tracking_type based Installation frequency', size= 16, fontsize=10, font=14, rotation=90)

cat_box_plot(x= 'tracking_type', y= 'size_kw_L', data=solar, ax=ax[1], xlabel='Tracking_type', 
                     title='Tracking_type vs Size_kw_L', size=16, fontsize=10, font=14, rotation=90)

# %% [markdown]
# ♦ **Initial observation:** <br>
#
# → The most popular `tracking system` is fixed.
#
# → Overall, `tracking system` does not seem related with `size_kw`.

# %% [markdown]
# # Outlier detection

# %%
from collections import Counter
def detect_outliers(df,n,features):
    """
    Takes a dataframe df of features and returns a list of the indices
    corresponding to the observations containing more than n outliers according
    to the Tukey method.
    """
    outlier_indices = []
    # iterate over features(columns)
    for col in features:
        # 1st quartile (25%)
        Q1 = np.percentile(df[col], 25)
        # 3rd quartile (75%)
        Q3 = np.percentile(df[col],75)
        # Interquartile range (IQR)
        IQR = Q3 - Q1
        # outlier step
        outlier_step = 3 * IQR
        # Determine a list of indices of outliers for feature col
        outlier_list_col = df[(df[col] < Q1 - outlier_step) | (df[col] > Q3 + outlier_step )].index
        # append the found outlier indices for col to the list of outlier indices 
        outlier_indices.extend(outlier_list_col)
    # select observations containing more than 2 outliers
    outlier_indices = Counter(outlier_indices)        
    multiple_outliers = list( k for k, v in outlier_indices.items() if v > n )  
    return multiple_outliers   

# detect outliers from Age, SibSp , Parch and Fare
Outliers_to_drop = detect_outliers(solar,1,['size_kw_L', 'annual_PV_prod_L', 'annual_insolation'])
solar.loc[Outliers_to_drop]
# Out:
# Empty DataFrame
# Columns: [state, date_installed, incentive_prog_names, size_kw, zipcode, installer, city, tech_1, county, annual_PV_prod, annual_insolation, tracking_type, zipcode_1, zipcode_2, zipcode_3, year, month, size_kw_L, annual_PV_prod_L]
# Index: []

# %%
Outliers_to_drop = detect_outliers(solar_val,1,['size_kw_L', 'annual_PV_prod_L', 'annual_insolation'])
solar_val.loc[Outliers_to_drop]
# Out:
# Empty DataFrame
# Columns: [state, date_installed, incentive_prog_names, size_kw, zipcode, installer, city, tech_1, county, annual_PV_prod, annual_insolation, tracking_type, zipcode_1, zipcode_2, zipcode_3, year, month, size_kw_L, annual_PV_prod_L]
# Index: []

# %% [markdown]
# # 2.B. Converting String Values into Numeric

# %% [markdown]
# Following step is not necessary: using ^2 and ^3 to the most important feature reduces standard deviation with the cross-validation prediction with ML models, thus ensuring better prediction with future data

# %%
solar['annual_PV_prod_L-s2'] = solar['annual_PV_prod_L']** 2
solar['annual_PV_prod_L-s3'] = solar['annual_PV_prod_L']** 3

solar_val['annual_PV_prod_L-s2'] = solar_val['annual_PV_prod_L']** 2
solar_val['annual_PV_prod_L-s3'] = solar_val['annual_PV_prod_L']** 3

print("Find most important features relative to target")
solar2 = solar.drop(columns=['size_kw', 'size_kw_L'])
corr = solar2.corrwith(solar['size_kw_L'])
corr = corr.sort_values(ascending = False)
corr
# Out:
# Find most important features relative to target
# annual_PV_prod_L-s2    0.970814
# annual_PV_prod_L       0.969760
# annual_PV_prod_L-s3    0.969683
# annual_PV_prod         0.907219
# year                   0.144847
# month                  0.007529
# annual_insolation     -0.052608
# zipcode_2             -0.185281
# zipcode_3             -0.185656
# zipcode_1             -0.189497
# zipcode               -0.196823
# dtype: float64

# %%
# Log transform of the skewed numerical features to lessen impact of outliers
# As a general rule of thumb, a skewness with an absolute value > 0.5 is considered at least moderately skewed
# annual_PV_prod and size_kw already transformed before
# For sanity check
skew_df = solar[['annual_insolation', 'size_kw_L', 'annual_PV_prod_L']] #'zipcode_1','year','month'
skewness = skew_df.apply(lambda x: skew(x))
skewness = skewness[abs(skewness) > 0.5]
print(str(skewness.shape[0]) + " skewed numerical features to log transform")
#skewed_features = skewness.index
#print(skewed_features)
#solar[skewed_features + '_L'] = np.log1p(solar[skewed_features])
# Out:
# 0 skewed numerical features to log transform

# %%
# Transforming some numerical variables that are really categorical
solar['year'] = solar['year'].apply(str)
solar['month'] = solar['month'].apply(str)
solar['zipcode_1'] = solar['zipcode_1'].apply(str)

solar_val['year'] = solar_val['year'].apply(str)
solar_val['month'] = solar_val['month'].apply(str)
solar_val['zipcode_1'] = solar_val['zipcode_1'].apply(str)

# %%
# Converting features into suitable form for modeling
solar1 = pd.get_dummies(solar)
solar_val = pd.get_dummies(solar_val)
solar1.shape, solar_val.shape
# Out:
# ((389802, 128), (97451, 128))

# %% [markdown]
# To reduce the feature space we can generate the **monotonic relationship** between categorical and target, but this is not required here.

# %% [markdown]
# # 3. Predictive Modeling

# %%
# separate dependent and independent variables
y = solar1['size_kw']
y_val = solar_val['size_kw']

y_L = solar1['size_kw_L']
y_val_L = solar_val['size_kw_L']

solar1 = solar1.drop(columns=['size_kw', 'size_kw_L', 'date_installed', 'zipcode','zipcode_2', 
                              'zipcode_3', 'annual_PV_prod']) 
                               
solar_val = solar_val.drop(columns=['size_kw', 'size_kw_L', 'date_installed', 'zipcode','zipcode_2', 
                              'zipcode_3', 'annual_PV_prod'])                         
solar1.shape, solar_val.shape
# Out:
# ((389802, 121), (97451, 121))

# %% [markdown]
# Standardization is an important step for all the models specially linear models or any other models where we calculate the distance

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
solar1_stndz = sc.fit_transform(solar1)
solar_val_stndz = sc.transform(solar_val)

# Use solar1_stndz and y_L for CV and train-test for normal evaluation
X_train,X_test,y_train,y_test = train_test_split(solar1_stndz, y_L, test_size = 0.3, random_state= 0)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((272861, 121), (116941, 121), (272861,), (116941,))

# %%
from sklearn.preprocessing import StandardScaler

from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso, ElasticNet

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_squared_log_error, make_scorer

# Additional validation function
def rmsle(y_true, y_pred):
    return np.sqrt(mean_squared_log_error(y_true, y_pred))

# False_rmsle is an error, lower is better
rmsle_scorer = make_scorer(rmsle, greater_is_better=False)

# %% [markdown]
# ## Create a baseline to check model performance improvement

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=123)

dr = DummyRegressor()
dr.fit(X_train, y_train)
#dr.score(X_test, y_test)
y_pred = dr.predict(X_test)

print(f'Dummy Regressor_r2: {r2_score(y_test, y_pred).round(4)}')
print(f'Dummy Regressor_mean_squared_error: {mean_squared_error(y_test, y_pred).round(4)}')
print(f'Dummy Regressor_RMSLE: {cross_val_score(dr, solar1_stndz, y_L, cv=kf, \
      scoring=rmsle_scorer).mean().round(4)}')
# Out:
# Dummy Regressor_r2: -0.0
# Dummy Regressor_mean_squared_error: 0.1855
# Dummy Regressor_RMSLE: -0.1554

# %% [markdown]
# ## 1. Linear Regression without regularization

# %%
# Linear Regression
lr = LinearRegression()
lr.fit(X_train, y_train)
#lr.score(X_test, y_test)
y_pred = lr.predict(X_test)
print(f'Linear Regression_r2: {r2_score(y_test, y_pred).round(4)}')
print(f'Linear Regression_Mean_squared_error: {mean_squared_error(y_test, y_pred).round(4)}')
# Out:
# Linear Regression_r2: 0.9987
# Linear Regression_Mean_squared_error: 0.0002

# %% [markdown]
# ### Linear Regression_cross validation

# %%
scores = cross_val_score(lr, solar1_stndz, y_L, cv=5)
print(f'Linear regression_cv_R2: {scores.mean().round(4), scores.std().round(6)}')

kf = KFold(n_splits=5, shuffle=True, random_state=123)
scores = cross_val_score(lr, solar1_stndz, y_L, cv=kf)
print(f'Linear regression_cv[with_shuffle]_R2: {scores.mean().round(4), scores.std().round(6)}')

nms_error = cross_val_score(lr, solar1_stndz, y_L, cv=kf, scoring='neg_mean_squared_error')
print(f'LR_cv[with_shuffle]_neg_mean_squared_error: {nms_error.mean().round(4), nms_error.std().round(6)}')
# Out:
# Linear regression_cv_R2: (0.9987, 2.5e-05)
# Linear regression_cv[with_shuffle]_R2: (0.9987, 1.7e-05)
# LR_cv[with_shuffle]_neg_mean_squared_error: (-0.0002, 4e-06)

# %% [markdown]
# Here we see the normal linear regression perform great. Cross-validation and cross-validation(shuffle, shuffle helps sometime when data is ordered) didn't improve the model, as model is already pretty good.
#
# Let's try regularized regression. We can try lasso as it reduces feature space.

# %% [markdown]
# ## 2. Linear Regression with Ridge regularization (L2 penalty)

# %%
# Regularized regression(ridge) without any tuning
rg = Ridge(alpha=1)
rg.fit(X_train, y_train)
#rg.score(X_test, y_test)

print(f'Ridge Regression_r2: {rg.score(X_test, y_test).round(4)}')
cv_score = cross_val_score(rg, solar1_stndz, y_L, cv=kf)
print(f'Overall model performance with cv_Mean_R2: {cv_score.mean().round(4)}', '\n'
f'Overall model performance with cv_Std_deviation: {cv_score.std().round(6)}')
# Out:
# Ridge Regression_r2: 0.9986
# Overall model performance with cv_Mean_R2: 0.9986
# Overall model performance with cv_Std_deviation: 2.4e-05

# %%
# Regularized regression(ridge) with hyperparameter tuning
from sklearn.model_selection import GridSearchCV
alphas = np.logspace(-6, 0, num=100) 
param_grid = {'alpha': alphas}
gs = GridSearchCV(rg, param_grid, cv=kf)
gs.fit(solar1_stndz, y_L)
print(f'best_score: {(gs.best_score_).round(6)}') 
ridge_best_alpha = gs.best_params_['alpha']
print(f'ridge_best_alpha: {ridge_best_alpha.round(6)}')

# Regularized regression(ridge) with tuning
rg = Ridge(alpha=ridge_best_alpha)
rg.fit(X_train, y_train)

print(f'Ridge Regression_r2: {rg.score(X_test, y_test).round(4)}')
cv_score = cross_val_score(rg, solar1_stndz, y_L, cv=kf)
print(f'Overall model performance with cv_Mean_R2: {cv_score.mean().round(4)}', '\n'
f'Overall model performance with cv_Std_deviation: {cv_score.std().round(6)}')
# Out:
# best_score: 0.998689
# ridge_best_alpha: 0.001072
# Ridge Regression_r2: 0.9987
# Overall model performance with cv_Mean_R2: 0.9987
# Overall model performance with cv_Std_deviation: 1.7e-05

# %% [markdown]
# Standard deviation reduces with hyperparameter tuning. At this point it is very hard to improve the score as it is almost perfect, reduction of the standard deviation is also impressive as it shows model stability.

# %%
df_results = pd.DataFrame(gs.cv_results_)

fig, axes = plt.subplots(1,2, figsize = (12,4))
df_results.plot(x='param_alpha', y='mean_test_score', ax=axes[0])
df_results[:55].plot(x='param_alpha', y='mean_test_score', ax=axes[1])
axes[1].xaxis.set_tick_params(rotation=45)
fig.suptitle('mean_test_score vs alpha', fontsize=15, y=1.01)

coefs = []
for alpha in alphas:
    rg = Ridge(alpha=alpha)
    rg.fit(X_train, y_train)
    coefs.append(rg.coef_)
df_coef = pd.DataFrame(index=alphas, data=np.array(coefs), columns=solar1.columns)

ax = df_coef.iloc[:,:17].plot(figsize=(12, 8), title=r'Shrinking Coefficient Values with Increasing $\alpha$')
ax.legend(bbox_to_anchor=(1, 1))
ax.set_xlabel(r'$\alpha$', size=25);

# %% [markdown]
# → Here we see as alpha or penalty increases in ridge regression, coefficient reduces but it never becomes 0.

# %% [markdown]
# #### Feature importance based on Ridge regression

# %%
# Plot important coefficients
rg = Ridge(alpha=ridge_best_alpha)
rg.fit(X_train, y_train)
coefs = pd.Series(rg.coef_, index = solar1.columns)
print("Ridge picked " + str(sum(coefs != 0)) + " features and eliminated the other " +  \
      str(sum(coefs == 0)) + " features")
imp_coefs = pd.concat([coefs.sort_values().head(2), coefs.sort_values().tail(2)])
imp_coefs.plot(kind = "barh", figsize=(10, 3))
plt.title("Important features in the Ridge Regression Model")
plt.show()
# Out:
# Ridge picked 121 features and eliminated the other 0 features

# %% [markdown]
# → As expected from EDA, `annual_PV_prod` or annual energy production and it's derrivatives are most important features for prediction.

# %% [markdown]
# #### Ridge regression performance with validation set

# %%
rg = Ridge(alpha=ridge_best_alpha)
rg.fit(X_train, y_train)
y_pred = rg.predict(solar_val_stndz)

print(f'Ridge Regression_r2_Validation_set: {rg.score(solar_val_stndz, y_val_L).round(6)}')
print(f'Ridge Regression_mean_squared_error: {mean_squared_error(y_val_L, y_pred).round(6)}')

ridge_cv_rmsle = cross_val_score(rg, solar_val_stndz, y_val_L, cv=kf, scoring=rmsle_scorer)
print(f'Ridge Regression_RMSLE: {ridge_cv_rmsle.mean().round(6), ridge_cv_rmsle.std().round(6)}')

cv_score = cross_val_score(rg, solar_val_stndz, y_val_L, cv=kf)
print(f'Overall model performance with cv_Mean_R2: {cv_score.mean().round(4)}', '\n'
f'Overall model performance with cv_Std_deviation_R2: {cv_score.std().round(6)}')
# Out:
# Ridge Regression_r2_Validation_set: 0.998632
# Ridge Regression_mean_squared_error: 0.000257
# Ridge Regression_RMSLE: (-0.006118, 9.2e-05)
# Overall model performance with cv_Mean_R2: 0.9986
# Overall model performance with cv_Std_deviation_R2: 4.6e-05

# %% [markdown]
# ►**Overall summary**<br>
# → Ridge regression performs great, however it doesn't improve beyond linear regression (as LR prediction was already great). Ridge standard deviation in model prediction is better than LR, thus it is a bit more stable (but again with a very fine line).
#
# → Benefit of Ridge is evident if I sample only a small fragment of train set and use that to predict test set, there linear regression doesn't perform well but ridge does. Thus ridge model is very stable.
#
# → **Next step**: Regularization or penalizing the coefficient as alpha increases are clearly evident in the plot. The characteristic of ridge regression is that it reduces the coefficient close to 0 but NOT 0, thus it can't act as feature selector unlike Lasso regression. This helps to remove unwanted features. As we know there are some features which might not be very important to predict `size_kw` we should try Lasso.

# %% [markdown]
# ## 3. Linear Regression with Lasso regularization (L1 penalty)

# %%
# Regularized regression(lasso) without any tuning
ls = Lasso(alpha=1)
ls.fit(X_train, y_train)
print(f'Lasso Regression_r2: {ls.score(X_test, y_test).round(4)}')
cv_score = cross_val_score(ls, solar1_stndz, y_L, cv=kf)
print(f'Overall model performance with cv_Mean: {cv_score.mean().round(4)}', '\n'
f'Overall model performance with cv_Std_deviation: {cv_score.std().round(6)}')
# Out:
# Lasso Regression_r2: -0.0
# Overall model performance with cv_Mean: -0.0001
# Overall model performance with cv_Std_deviation: 4.4e-05

# %% [markdown]
# Lasso with this penalty performs very poorly, we need to tune the `alpha` hyperparameter of lasso to improve its performance.

# %%
# Regularized regression(lasso) with hyperparameter tuning
from sklearn.model_selection import GridSearchCV
alphas = np.logspace(-6, 0, 100) 
param_grid = {'alpha': alphas}
gs = GridSearchCV(ls, param_grid, cv=kf)
gs.fit(solar1_stndz, y_L)
print(f'best_score: {(gs.best_score_).round(6)}')
lasso_best_alpha = gs.best_params_['alpha']
print(f'lasso_best_alpha: {lasso_best_alpha.round(6)}')

# Regularized regression(lasso) with tuning
ls = Lasso(alpha = lasso_best_alpha)
ls.fit(X_train, y_train)
#rg.score(X_test, y_test)
print(f'Lasso Regression_r2: {rg.score(X_test, y_test).round(4)}')
cv_score = cross_val_score(ls, solar1_stndz, y_L, cv=kf)
print(f'Overall model performance with cv_Mean: {cv_score.mean().round(4)}', '\n'
f'Overall model performance with cv_Std_deviation: {cv_score.std().round(6)}')
# Out:
# best_score: 0.998345
# lasso_best_alpha: 1e-06
# Lasso Regression_r2: 0.9987
# Overall model performance with cv_Mean: 0.9983
# Overall model performance with cv_Std_deviation: 3.6e-05

# %%
df_results = pd.DataFrame(gs.cv_results_)

fig, axes = plt.subplots(1,2, figsize = (12,4))
df_results.plot(x='param_alpha', y='mean_test_score', ax=axes[0])
df_results[:30].plot(x='param_alpha', y='mean_test_score', ax=axes[1]) 
axes[1].xaxis.set_tick_params(rotation=45)
fig.suptitle('mean_test_score vs alpha', fontsize=15, y=1.01)

coefs = []
for alpha in alphas:
    ls = Lasso(alpha=alpha)
    ls.fit(X_train, y_train)
    coefs.append(ls.coef_)
df_coef = pd.DataFrame(index=alphas, data=np.array(coefs), columns=solar1.columns)

ax = df_coef.iloc[:,:18].plot(figsize=(10, 8), title=r'Shrinking Coefficient Values with Increasing $\alpha$')
ax.legend(bbox_to_anchor=(1, 1))
ax.set_xlabel(r'$\alpha$', size=25);

# %% [markdown]
# #### Feature importance based on Lasso regression

# %%
# Plot important coefficients
ls = Lasso(alpha = lasso_best_alpha)
ls.fit(X_train, y_train)
coefs = pd.Series(ls.coef_, index = solar1.columns)
print("Lasso picked " + str(sum(coefs != 0)) + " features and eliminated the other " +  \
      str(sum(coefs == 0)) + " features")
imp_coefs = pd.concat([coefs.sort_values().head(3), coefs.sort_values().tail(3)])
imp_coefs.plot(kind = "barh",figsize=(10, 3))
plt.title("Important features in the Lasso Regression Model")
plt.show()
# Out:
# Lasso picked 107 features and eliminated the other 14 features

# %% [markdown]
# → As expected from EDA, annual_PV_prod or annual energy production and it's derrivatives are most important features for prediction (similar to ridge).

# %% [markdown]
# #### Lasso regression performance with validation set

# %%
ls = Lasso(alpha = lasso_best_alpha)
ls.fit(X_train, y_train)
y_pred = ls.predict(solar_val_stndz)
print(f'Lasso Regression_r2_Validation_set: {ls.score(solar_val_stndz, y_val_L).round(6)}')
print(f'Lasso Regression_mean_squared_error: {mean_squared_error(y_val_L, y_pred).round(6)}')

cv_score = cross_val_score(ls, solar_val_stndz, y_val_L, cv=kf)
print(f'Overall model performance with cv_Mean_R2: {cv_score.mean().round(4)}', '\n'
f'Overall model performance with cv_Std_deviation_R2: {cv_score.std().round(6)}')
# Out:
# Lasso Regression_r2_Validation_set: 0.998278
# Lasso Regression_mean_squared_error: 0.000323
# Overall model performance with cv_Mean_R2: 0.9983
# Overall model performance with cv_Std_deviation_R2: 6.4e-05

# %% [markdown]
# ►**Overall summary**<br>
# → Lasso regression performs poorly without hyperparameter tuning.<br>
#
# → As alpha is tuned, lasso performance improves greatly. However it doesn't improve beyond ridge regression (as ridge prediction was already great). Standard deviation of model performance is also a bit less than ridge.<br>
#
# → Benefit of Lasso (similar to ridge) is evident if I sample only a small fragment of train set and use that to predict test set, there linear regression doesn't perform well but lasso and ridge does. <br>
#
# → There is however a benefit of lasso over ridge. Here we see as penalty increases the coefficient of some of the features become 0 and thus it acts as a feature selector. With the best alpha that we got from hyperparameter tuning, we observe lasso removed 14 features. If that is important we can proceed with Lasso as it predicts pretty well.
#
# → **Next step**: We run ridge when we don't want to completely eliminate a feature, lasso when we want it to remove unimportant features. But when we are not sure which one to chose (when there are too many features and we don't have time to do EDA in each one of them) we can run elastic net. I run elastic net just for fun as I have clear understanding of the features.

# %% [markdown]
# ## 3. Linear Regression with ElasticNet regularization (L1 and L2 penalty)

# %%
# Regularized regression(ElasticNet) without any tuning
en= ElasticNet(alpha=1)
en.fit(X_train, y_train)
print(f'ElasticNet Regression_r2: {en.score(X_test, y_test).round(4)}')
cv_score = cross_val_score(en, solar1_stndz, y_L, cv=kf)
print(f'Overall model performance with cv_Mean: {cv_score.mean().round(4)}', '\n'
f'Overall model performance with cv_Std_deviation: {cv_score.std().round(6)}')
# Out:
# ElasticNet Regression_r2: -0.0
# Overall model performance with cv_Mean: -0.0001
# Overall model performance with cv_Std_deviation: 4.4e-05

# %% [markdown]
# ElasticNet with this penalty performs very poorly, we need to tune the alpha hyperparameter of ElasticNet to improve its performance.

# %%
# Regularized regression(ElasticNet) with hyperparameter tuning
from sklearn.model_selection import GridSearchCV
alphas = np.logspace(-6, 0, 100) 
param_grid = {'alpha': alphas}
gs = GridSearchCV(en, param_grid, cv=kf)
gs.fit(solar1_stndz, y_L) 
print(f'best_score: {(gs.best_score_).round(6)}')
en_best_alpha = gs.best_params_['alpha']
print(f'en_best_alpha: {en_best_alpha.round(6)}')

# Regularized regression(ElasticNet) with tuning
en = ElasticNet(alpha = en_best_alpha)
en.fit(X_train, y_train)
#rg.score(X_test, y_test)
print(f'ElasticNet Regression_r2: {en.score(X_test, y_test).round(4)}')
cv_score = cross_val_score(en, solar1_stndz, y_L, cv=kf)
print(f'Overall model performance with cv_Mean: {cv_score.mean().round(4)}', '\n'
f'Overall model performance with cv_Std_deviation: {cv_score.std().round(6)}')
# Out:
# best_score: 0.998345
# en_best_alpha: 1e-06
# ElasticNet Regression_r2: 0.9984
# Overall model performance with cv_Mean: 0.9983
# Overall model performance with cv_Std_deviation: 3.6e-05

# %%
df_results = pd.DataFrame(gs.cv_results_)

fig, axes = plt.subplots(1,2, figsize = (12,4))
df_results.plot(x='param_alpha', y='mean_test_score', ax=axes[0])
#axes[0].set_title('Overall mean_test_score vs alpha')
df_results[:35].plot(x='param_alpha', y='mean_test_score', ax=axes[1])
axes[1].xaxis.set_tick_params(rotation=45)
#axes[1].set_title('Zoomed mean_test_score vs alpha')
fig.suptitle('mean_test_score vs alpha', fontsize=15, y=1.01)

coefs = []
for alpha in alphas:
    en = ElasticNet(alpha=alpha)
    en.fit(X_train, y_train)
    coefs.append(en.coef_)
df_coef = pd.DataFrame(index=alphas, data=np.array(coefs), columns=solar1.columns)

ax = df_coef.iloc[:,:17].plot(figsize=(12, 8), title=r'Shrinking Coefficient Values with Increasing $\alpha$')
ax.legend(bbox_to_anchor=(1, 1))
ax.set_xlabel(r'$\alpha$', size=25);

# %% [markdown]
# #### Feature importance based on ElasticNet regression

# %%
# Plot important coefficients
en = ElasticNet(alpha = en_best_alpha)
en.fit(X_train, y_train)
coefs = pd.Series(en.coef_, index = solar1.columns)
print("ElasticNet picked " + str(sum(coefs != 0)) + " features and eliminated the other " +  \
      str(sum(coefs == 0)) + " features")
imp_coefs = pd.concat([coefs.sort_values().head(3), coefs.sort_values().tail(3)])
imp_coefs.plot(kind = "barh",figsize=(10, 3))
plt.title("Important features in the ElasticNet Regression Model")
plt.show()
# Out:
# ElasticNet picked 110 features and eliminated the other 11 features

# %% [markdown]
# → As expected from EDA, annual_PV_prod or annual energy production and it's derivatives are most important features for prediction (similar to ridge and lasso).

# %% [markdown]
# #### ElasticNet regression performance with validation set

# %%
en = ElasticNet(alpha = en_best_alpha)
en.fit(X_train, y_train)
y_pred = en.predict(solar_val_stndz)
print(f'ElasticNet Regression_r2_Validation_set: {en.score(solar_val_stndz, y_val_L).round(6)}')
print(f'ElasticNet Regression_mean_squared_error: {mean_squared_error(y_val_L, y_pred).round(6)}')

cv_score = cross_val_score(en, solar_val_stndz, y_val_L, cv=kf)
print(f'Overall model performance with cv_Mean_R2: {cv_score.mean().round(4)}', '\n'
f'Overall model performance with cv_Std_deviation_R2: {cv_score.std().round(6)}')
# Out:
# ElasticNet Regression_r2_Validation_set: 0.998278
# ElasticNet Regression_mean_squared_error: 0.000323
# Overall model performance with cv_Mean_R2: 0.9983
# Overall model performance with cv_Std_deviation_R2: 6.4e-05

# %% [markdown]
# ►**Overall summary**<br>
# → ElasticNet regression performs poorly without hyperparameter tuning.<br>
#
# → As alpha is tuned, ElasticNet performance improves greatly (very similar to lasso). However it doesn't improve beyond ridge regression (as ridge prediction was already great). Standard deviation of model performance is also a bit less than ridge.<br>
#
# → Benefit of ElasticNet (similar to lasso and ridge) is evident if I sample only a small fragment of train set and use that to predict test set, there linear regression doesn't perform well but ElasticNet does. <br>
#
# → There is however a benefit of ElasticNet over ridge (similar to lasso). As this includes both ridge and lasso alpha, it can act like feature selector. Therefore, we see at the best alpha value (selected by hyperparameter tuning) it eliminates 11 features (3 less than lasso elimination).
#
# → **Next step**: All the models perform well and show great performance with validation set. We can select either, but I will proceed with ridge regression (as lasso is only eliminating only 14) because of its performance and low standard deviation and thus we can expect least deviation in its prediction performance with future dataset.

# %% [markdown]
# ■ **Acknowledgements**<br>
#  * Vivek Rajasekharan (Insight Datascience fellow and Data scientist, AT&T) for constantly motivating me to finish this project and make a dataproduct.<br>
#  * Ted Petrou (Founder, DunderData) for a fantastic machine learning bootcamp and allowing me to serve as a TA in dunderdata.<br>
#  * Amazing datascience experts in kaggle, medium sharing their work over the platform.<br>
#  * Most importantly to Anna Wilde for her understanding and compassion as I needed to put in extra time and effort to finish this project after my work.
